# %%
from PIL import Image
import sys
import os
path='/root/lilei/颜色识别/'
path1='/root/lilei/test4/'
number=17
Y=0
for file in os.listdir(path):
    image=Image.open(path+file)
    number+=1
#     image = Image.open("/root/lilei/ctq1bak/云A4T115_201901051654001519_in.jpg_一汽丰田-威驰.jpg")
    a= image.getcolors(555555)
    b=sorted(a,reverse=True)
    #print b[0][1][0]
    #print(len(b))
    count =0
    f = open('/root/lilei/test2/color.txt').readlines()
    rgb = {}
    for i in f :
        s=i.replace("\n",'').split("\t")
    #     print(s,len(s))
        rgb[s[2]]=s[-1]
    def color(value):
        digit = list(map(str, range(10))) + list("ABCDEF")
        if isinstance(value, tuple):
            string = '#'
            for i in value:
                a1 = i // 16
                a2 = i % 16
                string += digit[a1] + digit[a2]
            return string
        elif isinstance(value, str):
            a1 = digit.index(value[1]) * 16 + digit.index(value[2])
            a2 = digit.index(value[3]) * 16 + digit.index(value[4])
            a3 = digit.index(value[5]) * 16 + digit.index(value[6])
            return (a1, a2, a3)     
    hei=0
    bai=0
    hong=0
    lan=0
    hui=0
    ying=0
    black=0
    white=0
    red=0
    blue=0
    gray=0
    silvery=0
    k=0
    white1=0
    bai1=0
    bai2=0
    for i in b :
    #     print i[0],rgb2hsv(i[1][0],i[1][1],i[1][2])
        result = {}
        rgbsum = i[1][0]+i[1][1]+i[1][2]
        minn = -1
        for r1 in rgb :
            s1= list(map(int ,r1.split(',')))
            #print (s1[0],s1[1],s1[2])   
            rgb1=abs(i[1][0]-s1[0])
            rgb2=abs(i[1][1]-s1[1])
            rgb3=abs(i[1][2]-s1[2])
            if rgb1 <60 and rgb2 < 60 and rgb3 <60 :
#                 print("r1========:",r1)
                rgbsum2 = abs(s1[0]+s1[1]+s1[2] - rgbsum)
#                 print("rgbsum2:",rgbsum2)
                result[rgbsum2]=rgb[r1]
#                 print("result[rgbsum2]",result[rgbsum2])
                if minn == -1:
                    minn = rgbsum2
#                     print("minn=-1:",minn)
                else :
                    if minn > rgbsum2:
                        minn = rgbsum2
#                         print("minn>rgbsum2:",minn)
#         print("-------------------")
#         print("minn:",minn)
        print((i[0],i[1],color((i[1])),result[minn]))
#         print("-------------------")
        count+=1
    #-----------------------测试一--------------------------------------------
    #     if result[minn]=='黑' :
    #         black+=1
    #     if result[minn]=='白':
    #         white+=1
    #     if result[minn]=='红':
    #         red+=1
    #     if result[minn]=='蓝':
    #         blue+=1
    #     if result[minn]=='灰':
    #         gray+=1
    #     if result[minn]=='银':
    #         silvery+=1  
    #     if count == 20 :
    #         data=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
    #         s=sorted(data,key=lambda x:x[1],reverse=True)
    #         print(s)
    #         if red!=0:
    #             print('红')
    #             break
    #         else:
    #             print(s[0][0])
    #         break
    #-------------------测试二-------------------------------------------------
    #     if result[minn]=='黑' :
    #         black+=1
    #     if result[minn]=='白':
    #         white+=1
    #     if result[minn]=='红':
    #         red+=1
    #     if result[minn]=='蓝':
    #         blue+=1
    #     if result[minn]=='灰':
    #         gray+=1
    #     if result[minn]=='银':
    #         silvery+=1  
    #     if count==50:
    #         data=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
    #         s=sorted(data,key=lambda x:x[1],reverse=True)
    #         if data[2][1] in (s[0][1],s[1][1],s[2][1]):
    #             print('红')
    #             break
    #         else:
    #             print(s[0][0])
    #         break
    #-------------------测试三--------------------------------------------------
        if result[minn]=='黑'or (result[minn]=='灰黑'and i[1][0]<50)or (result[minn]=='深黑' and i[1][0]<80):
            black=black+i[0]
        if result[minn]=='白' or result[minn]=='雪':
            white=white+i[0]
        if result[minn]=='雪':
            white1+=i[0]
        if result[minn]=='红'or (result[minn]=='灰黑' and i[1][0]>60 and i[1][1]<30)or(result[minn]=='深黑' and i[1][0]>80)or(result[minn]=='浅石板灰' and i[1][0]>=165)or (result[minn]=='暗淡的灰'and i[1][0]>=128):
            red=red+i[0]
        if result[minn]=='蓝':
            blue=blue+i[0]
        if result[minn]=='灰'or (result[minn]=='浅石板灰'and i[1][0]<165)or(result[minn]=='暗淡的灰'and i[1][0]<128):
            gray=gray+i[0]
        if result[minn]=='银':
            silvery=silvery+i[0]
        data1=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
        s1=sorted(data1,key=lambda x:x[1],reverse=True)
        if result[minn]=='黑'or (result[minn]=='灰黑'and i[1][0]<50)or (result[minn]=='深黑' and i[1][0]<80):
            hei+=1
        if result[minn]=='白':
            bai+=1
        if result[minn]=='红'or (result[minn]=='灰黑' and i[1][0]>60 and i[1][1]<30)or(result[minn]=='深黑' and i[1][0]>80)or(result[minn]=='浅石板灰' and i[1][0]>=165)or (result[minn]=='暗淡的灰'and i[1][0]>=128):
            hong+=1
        if result[minn]=='蓝':
            lan+=1
        if result[minn]=='灰'or (result[minn]=='浅石板灰'and i[1][0]<165)or(result[minn]=='暗淡的灰'and i[1][0]<128):
            hui+=1
        if result[minn]=='银':
            ying+=1
        data2=[('黑',hei),('白',bai),('红',hong),('蓝',lan),('灰',hui),('银',ying)]
        s2=sorted(data2,key=lambda x:x[1],reverse=True)
        name=file[0]
        if count==45:
            k=abs(data2[0][1]-data2[1][1])
            print("s1:",s1)
            print("s2:",s2)
            if (hong!=0 and (bai!=0 and abs(hong-bai)<5)) or (s2[0][0]=='红') or (bai==0 and hei!=0 and hong!=0):
                print('红')
                if name=='红':
                    Y+=1
                new_name='红'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif (s2[0][0]=='白' and (data2[1][0] in (s1[0][0],s1[1][0]) and k<5 ))or (white1>300 and (data2[1][0] in (s2[0][0],s2[1][0]))and(white1!=0 and (data2[1][0] in (s2[0][0],s2[1][0])) and float(white1/white)>0.9)):
                print('白')
                if name=='白':
                    Y+=1
                new_name='白'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif s1[0][1]>5000 and (s1[0][0] in s2[0][0],s2[1][0]):
                print(s1[0][0])
                if name==s1[0][0]:
                    Y+=1
                new_name=s1[0][0]+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif s2[0][0]=='黑' and s1[0][1]>1500:
                print('黑')
                if name=='黑':
                    Y+=1
                new_name='黑'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            else:
                print(s2[0][0])
                if name==s2[0][0]:
                    Y+=1
                new_name=s2[0][0]+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            break
print("accuary:",Y/number)
# Out:
# (4125, (34, 50, 76), '#22324C', '灰黑')
# (419, (45, 44, 58), '#2D2C3A', '黑')
# (296, (42, 42, 54), '#2A2A36', '黑')
# (231, (46, 46, 58), '#2E2E3A', '灰黑')
# (228, (43, 40, 57), '#2B2839', '黑')
# (223, (45, 45, 57), '#2D2D39', '黑')
# (217, (44, 43, 57), '#2C2B39', '黑')
# (182, (45, 42, 61), '#2D2A3D', '黑')
# (172, (43, 40, 59), '#2B283B', '黑')
# (171, (45, 42, 59), '#2D2A3B', '黑')
# (159, (46, 46, 56), '#2E2E38', '黑')
# (155, (47, 47, 59), '#2F2F3B', '灰黑')
# (155, (44, 43, 61), '#2C2B3D', '黑')
# (148, (43, 43, 55), '#2B2B37', '黑')
# (146, (53, 56, 65), '#353841', '黑')
# (146, (36, 35, 49), '#242331', '黑')
# (144, (48, 48, 60), '#30303C', '灰黑')
# (143, (44, 41, 58), '#2C293A', '黑')
# (142, (45, 44, 62), '#2D2C3E', '灰黑')
# (141, (44, 43, 59), '#2C2B3B', '黑')
# (135, (38, 37, 51), '#262533', '黑')
# (134, (42, 41, 55), '#2A2937', '黑')
# (133, (42, 39, 56), '#2A2738', '黑')
# (131, (46, 45, 61), '#2E2D3D', '灰黑')
# (130, (35, 34, 48), '#232230', '黑')
# (129, (43, 41, 55), '#2B2937', '黑')
# ...
