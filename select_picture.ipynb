# %%
import sys
import os
path='/root/lilei/ctq1bak/'
a=0
i=0
for file in os.listdir(path):
    #print(file)
    if 'jpg' in os.path.splitext(file)[0]:
        print(file)
        i+=1
    else:
        os.remove(path+file)
    a+=1
print(a)
print('-------------------')
print(i)
# Out:
# 桂EEE917_201901051127268488_in.jpg_华晨中华-中华骏捷.jpg
# 皖G96231_201901051535426452_in.jpg_长安汽车-长安之星.jpg
# 晋A02N89_201901051503064729_in.jpg_东风悦达起亚-起亚K5.jpg
# 冀F562VJ_201901051538471252_in.jpg_众泰汽车-众泰Z500.jpg
# 粤BTC967_201901051429336823_in.jpg_北京现代-索纳塔.jpg
# 渝D86567_201901051037056805_in.jpg_长安汽车-长安CS75.jpg
# 苏E2366Z_201901051416325759_in.jpg_别克(进口)-昂科雷.jpg
# 桂BDM539_201901051935379548_in.jpg_大众(进口)-夏朗.jpg
# 川AP5X60_201901051500401248_in.jpg_沃尔沃亚太-沃尔沃XC60.jpg
# 苏E2K275_201901051052253601_in.jpg_奇瑞汽车-艾瑞泽5.jpg
# 鲁RC906X_201901051950547728_in.jpg_大众(进口)-尚酷.jpg
# 冀J646R8_201901051252389336_in.jpg_江铃汽车-驭胜S350.jpg
# 渝AH081G_201901051556032337_in.jpg_长城汽车-哈弗H1.jpg
# 鲁JC9258_201901051435271953_in.jpg_一汽丰田-普拉多.jpg
# 湘AQ58B5_201901051555019400_in.jpg_宝马(进口)-宝马7系.jpg
# 冀J958Y9_201901051848350101_in.jpg_一汽-大众-高尔夫·嘉旅.jpg
# 鲁B82AS7_201901052040228544_in.jpg_长城汽车-哈弗H6.jpg
# 浙B113CV_201901051239002086_in.jpg_奔驰(进口)-奔驰B级.jpg
# 桂C02033_201901051839285862_in.jpg_斯巴鲁-傲虎.jpg
# ...
