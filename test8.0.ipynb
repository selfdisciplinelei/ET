# %%
from PIL import Image
import sys
import os
import cmath
path='/root/a_lilei/data/fake_white/'
number=0
Y=0
for file in os.listdir(path):
    image=Image.open(path+file)
    number+=1
    a= image.getcolors(555555)
    b=sorted(a,reverse=True)
    count =0
    f = open('/root/a_lilei/test2/color.txt').readlines()
    rgb = {}
    for i in f :
        s=i.replace("\n",'').split("\t")
        rgb[s[2]]=s[-1]
    def color(value):
        digit = list(map(str, range(10))) + list("ABCDEF")
        if isinstance(value, tuple):
            string = '#'
            for i in value:
                a1 = i // 16
                a2 = i % 16
                string += digit[a1] + digit[a2]
            return string
        elif isinstance(value, str):
            a1 = digit.index(value[1]) * 16 + digit.index(value[2])
            a2 = digit.index(value[3]) * 16 + digit.index(value[4])
            a3 = digit.index(value[5]) * 16 + digit.index(value[6])
            return (a1, a2, a3)     
    hei=0
    bai=0
    hong=0
    lan=0
    hui=0
    ying=0
    black=0
    white=0
    red=0
    blue=0
    gray=0
    silvery=0
    k=0
    white1=0
    white2=0
    bai1=0
    bai2=0
    for i in b :
        result = {}
        rgbsum = i[1][0]+i[1][1]+i[1][2]
        minn = -1
        for r1 in rgb :
            s1= list(map(int ,r1.split(',')))  
            rgb1=abs(i[1][0]-s1[0])
            rgb2=abs(i[1][1]-s1[1])
            rgb3=abs(i[1][2]-s1[2])
            if rgb1 <60 and rgb2 < 60 and rgb3 <60 :
                rgbsum2 = abs(s1[0]+s1[1]+s1[2] - rgbsum)
                result[rgbsum2]=rgb[r1]
                if minn == -1:
                    minn = rgbsum2
                else :
                    if minn > rgbsum2:
                        minn = rgbsum2
#         print((i[0],i[1],color((i[1])),result[minn]))
        count+=1
    #-------------------测试三--------------------------------------------------
        if result[minn]=='黑'or(result[minn]=='玫瑰棕色'and i[1][0]<178)or (result[minn]=='灰黑'and i[1][0]<50)or (result[minn]=='深黑' and i[1][0]<80):
            black=black+i[0]
            hei+=1
        if result[minn]=='白':
            white2=white2+i[0]
            bai+=1
        if result[minn]=='雪':
            white1+=i[0]
            bai+=1
        if (result[minn]=='红')or(result[minn]=='玫瑰棕色'and i[1][0]>=178)or (result[minn]=='灰黑' and i[1][0]>60 and i[1][1]<45)or(result[minn]=='深黑' and i[1][0]>80)or(result[minn]=='浅石板灰' and i[1][0]>165)or (result[minn]=='暗淡的灰'and i[1][0]>=120)or(result[minn]=='马鞍棕色' and i[1][0]>90) :
            red=red+i[0]
            hong+=1
        white=white1+white2
        data1=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
        s1=sorted(data1,key=lambda x:x[1],reverse=True)
        data2=[('黑',hei),('白',bai),('红',hong),('蓝',lan),('灰',hui),('银',ying)]
        s2=sorted(data2,key=lambda x:x[1],reverse=True)
        name=file[0]
        if count==15:
            data_1=s1
            data_2=s2
        if count==20:
            data2_1=s1
            data2_2=s2
        if count==30:
            data3_1=s1
            data3_2=s2
        if count==45:
            k=abs(data2[0][1]-data2[1][1])
            with open('color_data.txt','w') as f:
                f.write(str(s1))
                f.write(str(s2))
            print("s1:",s1)
            print("s2:",s2)
            print("data_1:",data_1)
            print("data_2:",data_2)
            print("data2_1",data2_1)
            print("data2_2",data2_2)
            print("data3_1",data3_1)
            print("data3_2",data3_2)
            if (hong!=0 and (bai!=0 and abs(hong-bai)<5)and data2[2][0] in (s2[0][0],s2[1][0]))or(s1[0][0]=='黑'and s2[0][0]=='黑'and hong!=0)or (s2[0][0]=='红') or (bai==0 and hei!=0 and hong!=0):
                print('红')
                if name=='红':
                    Y+=1
                new_name='红'+str(number)+'.jpg'
                os.rename(path+file,path+file+'_'+new_name)
                break
            elif (s2[0][0]=='黑' and s1[0][0]=='黑')or(s1[0][0]=='黑' and s2[1][0]=='黑' and s1[0][1]>4000):
                print('黑')
                if name=='黑':
                    Y+=1
                new_name='黑'+str(number)+'.jpg'
                os.rename(path+file,path+file+'_'+new_name)
                break
            elif (s1[0][0]=='白'and s2[0][0]=='白') or(s1[0][0]=='白' and s2[1][0]=='白')or(s2[0][0]=='白'and s1[1][0]=='白') :
                print('白')
                if name=='白':
                    Y+=1
                new_name='白'+str(number)+'.jpg'
                os.rename(path+file,path+file+'_'+new_name)
                break
#             elif s1[0][1]>5000 and (s1[0][0] in (s2[0][0],s2[1][0])):
#                 print(s1[0][0])
#                 if name==s1[0][0]:
#                     Y+=1
#                 new_name=s1[0][0]+str(number)+'.jpg'
#                 os.rename(path+file,path+file+'_'+new_name)
#                 break
            
#             else:
#                 print(s2[0][0])
#                 if name==s2[0][0]:
#                     Y+=1
#                 new_name=s2[0][0]+str(number)+'.jpg'
#                 os.rename(path+file,path+file+'_'+new_name)
#                 break
            break
print("accuary:",Y/number)
print("count:",number)
print("yes:",Y)
# Out:
# s1: [('黑', 7163), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 43), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 4331), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 15), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 4920), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 20), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 5953), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 30), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 4604), ('白', 3162), ('红', 163), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 21), ('黑', 11), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 3878), ('白', 1174), ('红', 163), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('白', 6), ('黑', 5), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 3878), ('白', 1759), ('红', 163), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('白', 10), ('黑', 5), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 4008), ('白', 2558), ('红', 163), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('白', 16), ('黑', 6), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 13368), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 31), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 9669), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 14), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 10821), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 18), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 11737), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 22), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 5994), ('白', 932), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 38), ('白', 7), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 4653), ('白', 833), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 10), ('白', 5), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 4951), ('白', 833), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 15), ('白', 5), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 5401), ('白', 889), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 24), ('白', 6), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 7318), ('白', 446), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 38), ('白', 5), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 5407), ('白', 214), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 13), ('白', 2), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 5831), ('白', 214), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 18), ('白', 2), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 6387), ('白', 373), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 25), ('白', 4), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 4331), ('白', 503), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 26), ('白', 18), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 3901), ('白', 164), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 10), ('白', 5), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 4018), ('白', 193), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 14), ('白', 6), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 4130), ('白', 355), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 18), ('白', 12), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 7836), ('白', 3889), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 24), ('黑', 13), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 7165), ('白', 1564), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 8), ('白', 7), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 7165), ('白', 2408), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('白', 12), ('黑', 8), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 7594), ('白', 3088), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('白', 17), ('黑', 11), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 1972), ('白', 692), ('红', 169), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 12), ('白', 9), ('红', 2), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 1620), ('白', 117), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 7), ('白', 1), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 1620), ('白', 117), ('红', 115), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 7), ('白', 1), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 1775), ('白', 468), ('红', 115), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 9), ('白', 5), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# s1: [('黑', 4699), ('白', 823), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 12), ('白', 12), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 4350), ('白', 421), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 4), ('白', 3), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 4403), ('白', 478), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 5), ('白', 4), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 4448), ('白', 570), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 6), ('白', 6), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 7142), ('白', 1292), ('红', 166), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 25), ('白', 8), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 4821), ('白', 645), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 9), ('白', 3), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 5166), ('白', 819), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 11), ('白', 4), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 6292), ('白', 819), ('红', 166), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 18), ('白', 4), ('红', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# s1: [('黑', 196), ('白', 113), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 2), ('白', 1), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('白', 113), ('黑', 101), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 1), ('白', 1), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 5114), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 43), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 3506), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 15), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 3834), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 20), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 4435), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 30), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# s1: [('黑', 5613), ('白', 1586), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 25), ('白', 14), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 4203), ('白', 300), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 12), ('白', 2), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_1 [('黑', 4579), ('白', 545), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data2_2 [('黑', 15), ('白', 4), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_1 [('黑', 5046), ('白', 997), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data3_2 [('黑', 19), ('白', 8), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# accuary: 0.0
# count: 13
# yes: 0

# %%
path = "/root/a_lilei/test4"
print(len(os.listdir(path)))
# Out:
# 96
