# %%
from PIL import Image
import sys
import os
path='/root/lilei/test1/'
path1='/root/lilei/test3/'
number=0
for file in os.listdir(path):
    image=Image.open(path+file)
    number+=1
#     image = Image.open("/root/lilei/ctq1bak/云A4T115_201901051654001519_in.jpg_一汽丰田-威驰.jpg")
    a= image.getcolors(555555)
    b=sorted(a,reverse=True)
    #print b[0][1][0]
    #print(len(b))
    count =0
    f = open('/root/lilei/test2/color.txt').readlines()
    rgb = {}
    for i in f :
        s=i.replace("\n",'').split("\t")
    #     print(s,len(s))
        rgb[s[2]]=s[-1]
    def color(value):
        digit = list(map(str, range(10))) + list("ABCDEF")
        if isinstance(value, tuple):
            string = '#'
            for i in value:
                a1 = i // 16
                a2 = i % 16
                string += digit[a1] + digit[a2]
            return string
        elif isinstance(value, str):
            a1 = digit.index(value[1]) * 16 + digit.index(value[2])
            a2 = digit.index(value[3]) * 16 + digit.index(value[4])
            a3 = digit.index(value[5]) * 16 + digit.index(value[6])
            return (a1, a2, a3)     
    hei=0
    bai=0
    hong=0
    lan=0
    hui=0
    ying=0
    black=0
    white=0
    red=0
    blue=0
    gray=0
    silvery=0
    k=0
    white1=0
    bai1=0
    bai2=0
    for i in b :
    #     print i[0],rgb2hsv(i[1][0],i[1][1],i[1][2])
        result = {}
        rgbsum = i[1][0]+i[1][1]+i[1][2]
        minn = -1
        for r1 in rgb :
            s1= list(map(int ,r1.split(',')))
            #print (s1[0],s1[1],s1[2])   
            rgb1=abs(i[1][0]-s1[0])
            rgb2=abs(i[1][1]-s1[1])
            rgb3=abs(i[1][2]-s1[2])
            if rgb1 <60 and rgb2 < 60 and rgb3 <60 :
#                 print("r1========:",r1)
                rgbsum2 = abs(s1[0]+s1[1]+s1[2] - rgbsum)
#                 print("rgbsum2:",rgbsum2)
                result[rgbsum2]=rgb[r1]
#                 print("result[rgbsum2]",result[rgbsum2])
                if minn == -1:
                    minn = rgbsum2
#                     print("minn=-1:",minn)
                else :
                    if minn > rgbsum2:
                        minn = rgbsum2
#                         print("minn>rgbsum2:",minn)
#         print("-------------------")
#         print("minn:",minn)
        print((i[0],i[1],color((i[1])),result[minn]))
#         print("-------------------")
        count+=1
    #-----------------------测试一--------------------------------------------
    #     if result[minn]=='黑' :
    #         black+=1
    #     if result[minn]=='白':
    #         white+=1
    #     if result[minn]=='红':
    #         red+=1
    #     if result[minn]=='蓝':
    #         blue+=1
    #     if result[minn]=='灰':
    #         gray+=1
    #     if result[minn]=='银':
    #         silvery+=1  
    #     if count == 20 :
    #         data=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
    #         s=sorted(data,key=lambda x:x[1],reverse=True)
    #         print(s)
    #         if red!=0:
    #             print('红')
    #             break
    #         else:
    #             print(s[0][0])
    #         break
    #-------------------测试二-------------------------------------------------
    #     if result[minn]=='黑' :
    #         black+=1
    #     if result[minn]=='白':
    #         white+=1
    #     if result[minn]=='红':
    #         red+=1
    #     if result[minn]=='蓝':
    #         blue+=1
    #     if result[minn]=='灰':
    #         gray+=1
    #     if result[minn]=='银':
    #         silvery+=1  
    #     if count==50:
    #         data=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
    #         s=sorted(data,key=lambda x:x[1],reverse=True)
    #         if data[2][1] in (s[0][1],s[1][1],s[2][1]):
    #             print('红')
    #             break
    #         else:
    #             print(s[0][0])
    #         break
    #-------------------测试三--------------------------------------------------
        if result[minn]=='黑':
            black=black+i[0]
        if result[minn]=='白' or result[minn]=='雪':
            white=white+i[0]
        if result[minn]=='雪':
            white1+=i[0]
        if result[minn]=='红'and i[1][0]>60:
            red=red+i[0]
    #     if result[minn]=='蓝':
    #         blue=blue+i[0]
    #     if result[minn]=='灰':
    #         gray=gray+i[0]
    #     if result[minn]=='银':
    #         silvery=silvery+i[0]
        data1=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
        s1=sorted(data1,key=lambda x:x[1],reverse=True)
        if result[minn]=='黑':
            hei+=1
        if result[minn]=='白':
            bai+=1
        if result[minn]=='红'and i[1][0]>60:
            hong+=1
    #     if result[minn]=='蓝':
    #         lan+=1
    #     if result[minn]=='灰':
    #         hui+=1
    #     if result[minn]=='银':
    #         ying+=1
        data2=[('黑',hei),('白',bai),('红',hong),('蓝',lan),('灰',hui),('银',ying)]
        s2=sorted(data2,key=lambda x:x[1],reverse=True)
        if count==45:
            k=abs(data2[0][1]-data2[1][1])
            print("s1:",s1)
            print("s2:",s2)
            if (hong!=0 and (bai!=0 and abs(hong-bai)<5)) or (s2[0][0]=='红') or (bai==0 and hei!=0 and hong!=0):
                print('红')
                new_name='红'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif (s2[0][0]=='白' and (data2[1][0] in (s2[0][0],s2[1][0]) and k<5 ))or (white1>300 and (data2[1][0] in (s2[0][0],s2[1][0]))):
                print('白')
                new_name='白'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif s1[0][1]>5000 and (s1[0][0] in s2[0][0],s2[1][0]):
                print(s1[0][0])
                new_name=s1[0][0]+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            elif s2[0][0]=='黑' and s1[0][1]>1500:
                print('黑')
                new_name='黑'+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            else:
                print(s2[0][0])
                new_name=s2[0][0]+str(number)+'.jpg'
                os.rename(path+file,path1+new_name)
                break
            break
# Out:
# (4167, (35, 45, 80), '#232D50', '红')
# (678, (13, 15, 14), '#0D0F0E', '黑')
# (651, (12, 14, 13), '#0C0E0D', '黑')
# (516, (11, 13, 12), '#0B0D0C', '黑')
# (454, (14, 16, 15), '#0E100F', '黑')
# (450, (15, 17, 16), '#0F1110', '黑')
# (368, (16, 18, 17), '#101211', '黑')
# (346, (17, 19, 18), '#111312', '黑')
# (339, (35, 46, 78), '#232E4E', '红')
# (329, (20, 22, 19), '#141613', '黑')
# (320, (23, 25, 22), '#171916', '黑')
# (319, (19, 21, 20), '#131514', '黑')
# (315, (21, 23, 20), '#151714', '黑')
# (308, (18, 20, 19), '#121413', '黑')
# (306, (10, 12, 11), '#0A0C0B', '黑')
# (302, (22, 24, 21), '#161815', '黑')
# (300, (35, 45, 81), '#232D51', '红')
# (256, (20, 22, 21), '#141615', '黑')
# (252, (22, 24, 23), '#161817', '黑')
# (243, (21, 23, 22), '#151716', '黑')
# (236, (9, 11, 10), '#090B0A', '黑')
# (206, (23, 25, 24), '#171918', '黑')
# (190, (19, 21, 18), '#131512', '黑')
# (180, (24, 26, 25), '#181A19', '黑')
# (180, (8, 10, 9), '#080A09', '黑')
# (169, (24, 26, 23), '#181A17', '黑')
# (161, (25, 27, 24), '#191B18', '黑')
# (161, (13, 13, 13), '#0D0D0D', '黑')
# (160, (14, 15, 17), '#0E0F11', '黑')
# (154, (12, 13, 15), '#0C0D0F', '黑')
# (151, (13, 14, 16), '#0D0E10', '黑')
# (138, (14, 14, 14), '#0E0E0E', '黑')
# (129, (11, 12, 14), '#0B0C0E', '黑')
# (127, (15, 16, 18), '#0F1012', '黑')
# (124, (17, 18, 20), '#111214', '黑')
# (121, (16, 17, 19), '#101113', '黑')
# (112, (7, 9, 8), '#070908', '黑')
# (111, (19, 19, 19), '#131313', '黑')
# (111, (18, 19, 21), '#121315', '黑')
# (109, (25, 27, 26), '#191B1A', '黑')
# (109, (19, 20, 22), '#131416', '黑')
# (102, (33, 46, 78), '#212E4E', '红')
# (96, (26, 28, 25), '#1A1C19', '黑')
# (94, (26, 28, 27), '#1A1C1B', '黑')
# (90, (22, 26, 27), '#161A1B', '黑')
# s1: [('黑', 9832), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 41), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (3695, (48, 58, 107), '#303A6B', '黑')
# (171, (48, 58, 109), '#303A6D', '黑')
# (163, (47, 59, 107), '#2F3B6B', '黑')
# (162, (47, 59, 109), '#2F3B6D', '黑')
# (141, (50, 57, 109), '#32396D', '黑')
# (127, (50, 58, 107), '#323A6B', '黑')
# (126, (114, 0, 34), '#720022', '红')
# (115, (112, 0, 24), '#700018', '红')
# (115, (50, 58, 105), '#323A69', '黑')
# (111, (115, 0, 33), '#730021', '红')
# (109, (114, 0, 36), '#720024', '红')
# (108, (112, 0, 25), '#700019', '红')
# (106, (113, 1, 26), '#71011A', '红')
# (105, (47, 60, 105), '#2F3C69', '黑')
# (103, (113, 1, 25), '#710119', '红')
# (98, (113, 0, 30), '#71001E', '红')
# (94, (115, 0, 31), '#73001F', '红')
# (92, (48, 59, 105), '#303B69', '黑')
# (88, (112, 0, 36), '#700024', '红')
# (88, (110, 0, 27), '#6E001B', '红')
# (87, (110, 0, 25), '#6E0019', '红')
# (87, (108, 0, 23), '#6C0017', '红')
# (79, (113, 0, 28), '#71001C', '红')
# (77, (114, 0, 33), '#720021', '红')
# (74, (114, 0, 26), '#72001A', '红')
# (74, (109, 0, 21), '#6D0015', '红')
# (71, (116, 0, 37), '#740025', '红')
# (71, (115, 0, 34), '#730022', '红')
# (71, (115, 0, 29), '#73001D', '红')
# (71, (109, 0, 29), '#6D001D', '红')
# (71, (109, 0, 23), '#6D0017', '红')
# (69, (114, 0, 28), '#72001C', '红')
# (68, (111, 0, 33), '#6F0021', '红')
# (68, (39, 42, 57), '#272A39', '黑')
# (66, (114, 0, 25), '#720019', '红')
# (65, (116, 0, 35), '#740023', '红')
# (65, (111, 0, 32), '#6F0020', '红')
# (64, (112, 15, 48), '#700F30', '红')
# (64, (110, 1, 24), '#6E0118', '红')
# (63, (116, 1, 34), '#740122', '红')
# (62, (111, 0, 35), '#6F0023', '红')
# (60, (118, 0, 34), '#760022', '红')
# (60, (112, 0, 27), '#70001B', '红')
# (59, (115, 0, 39), '#730027', '红')
# (59, (113, 0, 32), '#710020', '红')
# s1: [('黑', 4839), ('红', 2803), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('红', 35), ('黑', 10), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (2975, (26, 33, 43), '#1A212B', '黑')
# (264, (192, 197, 203), '#C0C5CB', '紫')
# (238, (95, 99, 98), '#5F6362', '灰')
# (218, (96, 100, 99), '#606463', '灰')
# (210, (97, 101, 100), '#616564', '灰')
# (205, (26, 33, 41), '#1A2129', '黑')
# (187, (25, 34, 43), '#19222B', '黑')
# (184, (220, 223, 228), '#DCDFE4', '灰')
# (182, (100, 101, 103), '#646567', '灰')
# (178, (94, 98, 97), '#5E6261', '灰')
# (171, (221, 224, 229), '#DDE0E5', '白')
# (170, (28, 32, 43), '#1C202B', '黑')
# (169, (98, 100, 99), '#626463', '灰')
# (165, (99, 101, 100), '#636564', '灰')
# (164, (218, 221, 226), '#DADDE2', '灰')
# (163, (26, 32, 44), '#1A202C', '黑')
# (158, (219, 222, 227), '#DBDEE3', '灰')
# (149, (194, 199, 205), '#C2C7CD', '紫')
# (147, (90, 94, 93), '#5A5E5D', '灰')
# (146, (94, 98, 99), '#5E6263', '灰')
# (143, (96, 98, 97), '#606261', '灰')
# (142, (97, 101, 102), '#616566', '灰')
# (142, (88, 92, 91), '#585C5B', '灰')
# (139, (97, 99, 98), '#616362', '灰')
# (139, (84, 85, 87), '#545557', '黑')
# (137, (89, 93, 92), '#595D5C', '灰')
# (136, (93, 97, 98), '#5D6162', '灰')
# (134, (98, 102, 101), '#626665', '灰')
# (134, (92, 96, 97), '#5C6061', '灰')
# (129, (25, 33, 44), '#19212C', '黑')
# (123, (91, 95, 94), '#5B5F5E', '灰')
# (122, (87, 91, 90), '#575B5A', '灰')
# (119, (228, 229, 233), '#E4E5E9', '白')
# (119, (188, 193, 197), '#BCC1C5', '白')
# (118, (193, 198, 204), '#C1C6CC', '紫')
# (118, (81, 83, 80), '#515350', '黑')
# (117, (187, 192, 196), '#BBC0C4', '白')
# (117, (100, 102, 101), '#646665', '灰')
# (117, (96, 100, 101), '#606465', '灰')
# (115, (189, 194, 198), '#BDC2C6', '白')
# (114, (95, 99, 100), '#5F6364', '灰')
# (113, (204, 211, 219), '#CCD3DB', '白')
# (111, (28, 32, 41), '#1C2029', '黑')
# (110, (205, 212, 220), '#CDD4DC', '白')
# (110, (101, 102, 104), '#656668', '灰')
# s1: [('黑', 4197), ('白', 864), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 9), ('白', 7), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (1306, (48, 63, 86), '#303F56', '黑')
# (92, (197, 199, 196), '#C5C7C4', '紫')
# (59, (197, 199, 198), '#C5C7C6', '紫')
# (58, (216, 218, 217), '#D8DAD9', '红')
# (54, (206, 203, 184), '#CECBB8', '紫')
# (51, (217, 219, 218), '#D9DBDA', '红')
# (48, (203, 200, 181), '#CBC8B5', '白')
# (46, (198, 200, 197), '#C6C8C5', '紫')
# (41, (199, 201, 196), '#C7C9C4', '紫')
# (40, (204, 201, 182), '#CCC9B6', '白')
# (39, (208, 210, 209), '#D0D2D1', '红')
# (39, (197, 200, 193), '#C5C8C1', '紫')
# (38, (219, 223, 232), '#DBDFE8', '白')
# (38, (212, 212, 210), '#D4D4D2', '白')
# (37, (213, 213, 211), '#D5D5D3', '白')
# (36, (205, 202, 183), '#CDCAB7', '紫')
# (35, (209, 209, 207), '#D1D1CF', '白')
# (34, (211, 211, 209), '#D3D3D1', '红')
# (34, (199, 201, 198), '#C7C9C6', '紫')
# (33, (214, 216, 215), '#D6D8D7', '白')
# (33, (213, 215, 212), '#D5D7D4', '白')
# (33, (207, 204, 185), '#CFCCB9', '紫')
# (33, (204, 205, 199), '#CCCDC7', '灰')
# (32, (210, 210, 208), '#D2D2D0', '红')
# (31, (215, 217, 214), '#D7D9D6', '白')
# (31, (208, 210, 207), '#D0D2CF', '白')
# (31, (201, 204, 197), '#C9CCC5', '紫')
# (30, (217, 213, 201), '#D9D5C9', '红')
# (30, (213, 215, 214), '#D5D7D6', '白')
# (30, (210, 212, 211), '#D2D4D3', '白')
# (30, (201, 203, 198), '#C9CBC6', '紫')
# (30, (198, 200, 195), '#C6C8C3', '紫')
# (30, (191, 191, 191), '#BFBFBF', '白')
# (29, (219, 222, 231), '#DBDEE7', '白')
# (29, (217, 214, 199), '#D9D6C7', '红')
# (29, (209, 211, 210), '#D1D3D2', '红')
# (29, (204, 206, 205), '#CCCECD', '白')
# (29, (204, 201, 184), '#CCC9B8', '白')
# (29, (203, 200, 183), '#CBC8B7', '白')
# (29, (200, 202, 199), '#C8CAC7', '紫')
# (29, (200, 202, 197), '#C8CAC5', '紫')
# (28, (207, 209, 206), '#CFD1CE', '白')
# (28, (205, 202, 185), '#CDCAB9', '紫')
# (27, (215, 217, 216), '#D7D9D8', '白')
# (27, (212, 214, 213), '#D4D6D5', '白')
# s1: [('黑', 1306), ('白', 652), ('红', 302), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 20), ('红', 8), ('黑', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (1794, (49, 74, 115), '#314A73', '黑')
# (249, (49, 73, 117), '#314975', '黑')
# (210, (49, 74, 114), '#314A72', '黑')
# (151, (28, 27, 33), '#1C1B21', '黑')
# (141, (47, 75, 115), '#2F4B73', '黑')
# (140, (50, 73, 115), '#324973', '黑')
# (139, (27, 27, 35), '#1B1B23', '黑')
# (137, (27, 28, 33), '#1B1C21', '黑')
# (133, (47, 75, 114), '#2F4B72', '黑')
# (131, (29, 26, 33), '#1D1A21', '黑')
# (128, (27, 26, 31), '#1B1A1F', '黑')
# (126, (27, 26, 32), '#1B1A20', '黑')
# (121, (26, 26, 34), '#1A1A22', '黑')
# (119, (28, 27, 35), '#1C1B23', '黑')
# (117, (26, 27, 32), '#1A1B20', '黑')
# (111, (47, 74, 117), '#2F4A75', '黑')
# (109, (29, 27, 32), '#1D1B20', '黑')
# (109, (26, 27, 31), '#1A1B1F', '黑')
# (108, (50, 73, 114), '#324972', '黑')
# (105, (28, 28, 36), '#1C1C24', '黑')
# (103, (28, 27, 32), '#1C1B20', '黑')
# (102, (25, 26, 31), '#191A1F', '黑')
# (101, (50, 73, 117), '#324975', '黑')
# (94, (29, 28, 34), '#1D1C22', '黑')
# (91, (27, 26, 34), '#1B1A22', '黑')
# (90, (27, 27, 37), '#1B1B25', '黑')
# (87, (26, 25, 31), '#1A191F', '黑')
# (85, (24, 25, 30), '#18191E', '黑')
# (83, (30, 27, 36), '#1E1B24', '黑')
# (82, (30, 28, 39), '#1E1C27', '黑')
# (82, (28, 28, 38), '#1C1C26', '黑')
# (82, (27, 28, 32), '#1B1C20', '黑')
# (81, (29, 28, 36), '#1D1C24', '黑')
# (81, (28, 25, 32), '#1C1920', '黑')
# (80, (26, 25, 30), '#1A191E', '黑')
# (79, (25, 26, 30), '#191A1E', '黑')
# (78, (29, 29, 39), '#1D1D27', '黑')
# (78, (28, 26, 37), '#1C1A25', '黑')
# (77, (28, 26, 31), '#1C1A1F', '黑')
# (75, (31, 29, 40), '#1F1D28', '黑')
# (75, (30, 27, 34), '#1E1B22', '黑')
# (74, (31, 30, 36), '#1F1E24', '黑')
# (73, (30, 29, 35), '#1E1D23', '黑')
# (73, (28, 29, 34), '#1C1D22', '黑')
# (72, (31, 30, 38), '#1F1E26', '黑')
# s1: [('黑', 6456), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 45), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (4666, (21, 32, 26), '#15201A', '黑')
# (1042, (17, 18, 20), '#111214', '黑')
# (1023, (16, 17, 19), '#101113', '黑')
# (876, (15, 16, 18), '#0F1012', '黑')
# (847, (15, 17, 16), '#0F1110', '黑')
# (623, (18, 19, 21), '#121315', '黑')
# (603, (14, 15, 17), '#0E0F11', '黑')
# (595, (14, 16, 15), '#0E100F', '黑')
# (541, (16, 18, 17), '#101211', '黑')
# (479, (13, 14, 16), '#0D0E10', '黑')
# (476, (18, 20, 19), '#121413', '黑')
# (420, (17, 19, 18), '#111312', '黑')
# (418, (13, 15, 14), '#0D0F0E', '黑')
# (395, (19, 21, 20), '#131514', '黑')
# (318, (253, 253, 253), '#FDFDFD', '雪')
# (302, (12, 14, 13), '#0C0E0D', '黑')
# (301, (12, 13, 15), '#0C0D0F', '黑')
# (300, (35, 39, 42), '#23272A', '黑')
# (300, (34, 38, 41), '#222629', '黑')
# (293, (21, 22, 24), '#151618', '黑')
# (271, (22, 23, 25), '#161719', '黑')
# (248, (19, 20, 22), '#131416', '黑')
# (245, (36, 40, 43), '#24282B', '黑')
# (226, (36, 41, 44), '#24292C', '黑')
# (224, (20, 21, 23), '#141517', '黑')
# (220, (33, 37, 40), '#212528', '黑')
# (199, (37, 41, 44), '#25292C', '黑')
# (194, (23, 24, 26), '#17181A', '黑')
# (193, (24, 25, 27), '#18191B', '黑')
# (191, (18, 19, 23), '#121317', '黑')
# (181, (19, 20, 24), '#131418', '黑')
# (180, (35, 40, 43), '#23282B', '黑')
# (175, (20, 22, 21), '#141615', '黑')
# (172, (20, 21, 25), '#141519', '黑')
# (171, (135, 148, 156), '#87949C', '灰')
# (171, (30, 34, 37), '#1E2225', '黑')
# (164, (32, 36, 39), '#202427', '黑')
# (160, (215, 225, 234), '#D7E1EA', '白')
# (155, (132, 145, 151), '#849197', '灰')
# (153, (11, 12, 14), '#0B0C0E', '黑')
# (149, (216, 226, 235), '#D8E2EB', '白')
# (148, (31, 35, 38), '#1F2326', '黑')
# (148, (29, 33, 36), '#1D2124', '黑')
# (147, (217, 227, 236), '#D9E3EC', '白')
# (142, (194, 208, 219), '#C2D0DB', '白')
# s1: [('黑', 18203), ('白', 916), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 38), ('白', 4), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (2610, (47, 53, 69), '#2F3545', '黑')
# (326, (47, 52, 71), '#2F3447', '黑')
# (311, (208, 213, 209), '#D0D5D1', '红')
# (283, (47, 53, 67), '#2F3543', '红')
# (282, (223, 227, 228), '#DFE3E4', '白')
# (273, (255, 255, 255), '#FFFFFF', '白')
# (269, (224, 225, 229), '#E0E1E5', '白')
# (257, (223, 224, 226), '#DFE0E2', '白')
# (252, (218, 222, 221), '#DADEDD', '白')
# (250, (225, 227, 226), '#E1E3E2', '白')
# (247, (207, 212, 208), '#CFD4D0', '红')
# (241, (221, 225, 224), '#DDE1E0', '灰')
# (237, (224, 225, 227), '#E0E1E3', '白')
# (236, (225, 226, 230), '#E1E2E6', '白')
# (231, (219, 223, 222), '#DBDFDE', '灰')
# (227, (222, 226, 227), '#DEE2E3', '白')
# (223, (216, 220, 219), '#D8DCDB', '红')
# (220, (221, 222, 226), '#DDDEE2', '灰')
# (212, (217, 221, 220), '#D9DDDC', '红')
# (205, (220, 224, 223), '#DCE0DF', '灰')
# (201, (224, 226, 225), '#E0E2E1', '白')
# (201, (222, 226, 225), '#DEE2E1', '白')
# (201, (222, 223, 227), '#DEDFE3', '白')
# (197, (215, 219, 218), '#D7DBDA', '红')
# (194, (209, 214, 210), '#D1D6D2', '白')
# (191, (225, 226, 228), '#E1E2E4', '白')
# (184, (210, 215, 211), '#D2D7D3', '白')
# (173, (222, 223, 225), '#DEDFE1', '灰')
# (167, (214, 219, 215), '#D6DBD7', '白')
# (163, (223, 224, 228), '#DFE0E4', '白')
# (161, (255, 255, 253), '#FFFFFD', '白')
# (158, (216, 217, 219), '#D8D9DB', '红')
# (156, (219, 220, 222), '#DBDCDE', '白')
# (155, (46, 53, 69), '#2E3545', '黑')
# (154, (49, 52, 69), '#313445', '黑')
# (150, (211, 216, 212), '#D3D8D4', '白')
# (145, (46, 53, 71), '#2E3547', '黑')
# (143, (220, 221, 225), '#DCDDE1', '灰')
# (140, (216, 221, 217), '#D8DDD9', '红')
# (134, (218, 219, 221), '#DADBDD', '红')
# (132, (213, 218, 214), '#D5DAD6', '白')
# (129, (217, 222, 218), '#D9DEDA', '红')
# (123, (209, 215, 211), '#D1D7D3', '白')
# (122, (213, 217, 216), '#D5D9D8', '白')
# (120, (219, 220, 224), '#DBDCE0', '灰')
# s1: [('白', 4629), ('黑', 3390), ('红', 1751), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 23), ('红', 9), ('黑', 5), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (3597, (33, 67, 102), '#214366', '黑')
# (187, (189, 201, 213), '#BDC9D5', '紫')
# (186, (190, 202, 214), '#BECAD6', '紫')
# (156, (191, 203, 215), '#BFCBD7', '紫')
# (138, (188, 200, 212), '#BCC8D4', '紫')
# (135, (184, 198, 211), '#B8C6D3', '紫')
# (116, (187, 199, 211), '#BBC7D3', '紫')
# (112, (184, 198, 209), '#B8C6D1', '紫')
# (110, (171, 185, 196), '#ABB9C4', '棕')
# (109, (169, 183, 194), '#A9B7C2', '棕')
# (107, (170, 184, 195), '#AAB8C3', '棕')
# (86, (186, 198, 210), '#BAC6D2', '紫')
# (86, (52, 59, 67), '#343B43', '黑')
# (85, (187, 201, 214), '#BBC9D6', '紫')
# (81, (168, 182, 193), '#A8B6C1', '棕')
# (80, (183, 197, 210), '#B7C5D2', '紫')
# (73, (51, 58, 66), '#333A42', '黑')
# (71, (192, 204, 216), '#C0CCD8', '紫')
# (71, (167, 181, 192), '#A7B5C0', '棕')
# (69, (186, 202, 217), '#BACAD9', '紫')
# (67, (185, 199, 212), '#B9C7D4', '紫')
# (66, (158, 170, 182), '#9EAAB6', '白')
# (64, (185, 199, 210), '#B9C7D2', '紫')
# (62, (181, 195, 206), '#B5C3CE', '白')
# (61, (183, 197, 208), '#B7C5D0', '白')
# (59, (182, 196, 207), '#B6C4CF', '白')
# (59, (169, 183, 196), '#A9B7C4', '棕')
# (58, (172, 186, 197), '#ACBAC5', '白')
# (58, (54, 58, 67), '#363A43', '黑')
# (57, (185, 201, 216), '#B9C9D8', '紫')
# (56, (188, 202, 215), '#BCCAD7', '紫')
# (56, (124, 141, 157), '#7C8D9D', '灰')
# (56, (123, 140, 156), '#7B8C9C', '灰')
# (55, (134, 147, 164), '#8693A4', '白')
# (54, (185, 197, 209), '#B9C5D1', '紫')
# (54, (184, 196, 208), '#B8C4D0', '白')
# (54, (50, 57, 65), '#323941', '黑')
# (53, (181, 193, 205), '#B5C1CD', '白')
# (52, (186, 200, 213), '#BAC8D5', '紫')
# (52, (174, 188, 199), '#AEBCC7', '白')
# (51, (127, 144, 160), '#7F90A0', '灰')
# (49, (173, 187, 198), '#ADBBC6', '白')
# (49, (135, 152, 168), '#8798A8', '白')
# (48, (134, 151, 167), '#8697A7', '白')
# (47, (187, 200, 209), '#BBC8D1', '紫')
# s1: [('黑', 3868), ('白', 666), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 12), ('黑', 5), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (3719, (31, 41, 76), '#1F294C', '黑')
# (427, (255, 255, 255), '#FFFFFF', '白')
# (231, (255, 255, 253), '#FFFFFD', '白')
# (143, (255, 254, 255), '#FFFEFF', '白')
# (111, (29, 42, 76), '#1D2A4C', '黑')
# (109, (254, 254, 254), '#FEFEFE', '白')
# (104, (31, 41, 77), '#1F294D', '红')
# (89, (254, 255, 255), '#FEFFFF', '白')
# (88, (140, 156, 156), '#8C9C9C', '白')
# (86, (31, 42, 74), '#1F2A4A', '黑')
# (82, (137, 159, 156), '#899F9C', '白')
# (79, (140, 156, 155), '#8C9C9B', '白')
# (78, (255, 253, 255), '#FFFDFF', '白')
# (78, (32, 40, 76), '#20284C', '黑')
# (77, (138, 156, 156), '#8A9C9C', '白')
# (76, (139, 158, 156), '#8B9E9C', '白')
# (76, (138, 157, 155), '#8A9D9B', '白')
# (76, (29, 42, 77), '#1D2A4D', '黑')
# (72, (255, 251, 255), '#FFFBFF', '白')
# (72, (140, 155, 158), '#8C9B9E', '白')
# (68, (138, 159, 154), '#8A9F9A', '白')
# (65, (138, 158, 157), '#8A9E9D', '白')
# (64, (255, 253, 254), '#FFFDFE', '白')
# (64, (139, 157, 157), '#8B9D9D', '白')
# (62, (137, 157, 156), '#899D9C', '白')
# (62, (137, 157, 155), '#899D9B', '白')
# (62, (136, 156, 155), '#889C9B', '白')
# (61, (254, 254, 252), '#FEFEFC', '雪')
# (61, (139, 157, 159), '#8B9D9F', '白')
# (61, (136, 158, 156), '#889E9C', '白')
# (60, (253, 254, 255), '#FDFEFF', '白')
# (60, (138, 156, 158), '#8A9C9E', '白')
# (60, (137, 159, 157), '#899F9D', '白')
# (58, (139, 160, 155), '#8BA09B', '白')
# (57, (138, 158, 156), '#8A9E9C', '白')
# (56, (255, 252, 255), '#FFFCFF', '白')
# (56, (139, 153, 162), '#8B99A2', '白')
# (56, (32, 41, 74), '#20294A', '黑')
# (55, (141, 155, 158), '#8D9B9E', '白')
# (52, (136, 158, 155), '#889E9B', '白')
# (51, (255, 255, 251), '#FFFFFB', '白')
# (51, (137, 158, 153), '#899E99', '白')
# (50, (254, 255, 250), '#FEFFFA', '雪')
# (50, (254, 254, 255), '#FEFEFF', '白')
# (49, (29, 42, 74), '#1D2A4A', '黑')
# s1: [('黑', 4175), ('白', 3045), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 35), ('黑', 7), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (3698, (17, 21, 32), '#111520', '黑')
# (340, (56, 10, 12), '#380A0C', '黑')
# (335, (59, 11, 11), '#3B0B0B', '红')
# (244, (55, 9, 11), '#37090B', '黑')
# (237, (60, 12, 12), '#3C0C0C', '红')
# (234, (58, 10, 10), '#3A0A0A', '红')
# (223, (61, 13, 13), '#3D0D0D', '红')
# (203, (5, 5, 5), '#050505', '黑')
# (195, (65, 10, 15), '#410A0F', '红')
# (193, (57, 8, 11), '#39080B', '红')
# (186, (64, 9, 12), '#40090C', '红')
# (182, (65, 8, 14), '#41080E', '红')
# (179, (64, 9, 14), '#40090E', '红')
# (177, (66, 14, 16), '#420E10', '红')
# (175, (58, 9, 12), '#3A090C', '红')
# (174, (57, 11, 13), '#390B0D', '红')
# (174, (56, 7, 10), '#38070A', '黑')
# (174, (4, 4, 6), '#040406', '黑')
# (171, (4, 4, 4), '#040404', '黑')
# (170, (6, 6, 6), '#060606', '黑')
# (164, (54, 8, 10), '#36080A', '黑')
# (161, (65, 10, 13), '#410A0D', '红')
# (161, (5, 7, 6), '#050706', '黑')
# (161, (3, 3, 3), '#030303', '黑')
# (154, (68, 9, 15), '#44090F', '红')
# (152, (3, 3, 5), '#030305', '黑')
# (150, (63, 11, 15), '#3F0B0F', '红')
# (144, (17, 21, 33), '#111521', '黑')
# (142, (3, 4, 6), '#030406', '黑')
# (140, (64, 12, 14), '#400C0E', '红')
# (138, (5, 5, 7), '#050507', '黑')
# (137, (66, 9, 15), '#42090F', '红')
# (135, (59, 10, 13), '#3B0A0D', '红')
# (134, (62, 14, 14), '#3E0E0E', '红')
# (134, (4, 6, 5), '#040605', '黑')
# (133, (67, 15, 17), '#430F11', '红')
# (133, (10, 10, 10), '#0A0A0A', '黑')
# (130, (63, 8, 11), '#3F080B', '红')
# (124, (65, 13, 15), '#410D0F', '红')
# (121, (2, 3, 5), '#020305', '黑')
# (120, (11, 11, 11), '#0B0B0B', '黑')
# (116, (2, 2, 2), '#020202', '黑')
# (115, (63, 15, 15), '#3F0F0F', '红')
# (114, (61, 9, 13), '#3D090D', '红')
# (112, (3, 5, 4), '#030504', '黑')
# s1: [('黑', 6972), ('红', 2634), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 21), ('红', 17), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (1733, (47, 56, 71), '#2F3847', '黑')
# (242, (90, 92, 105), '#5A5C69', '灰')
# (234, (91, 93, 106), '#5B5D6A', '灰')
# (211, (85, 89, 101), '#555965', '灰')
# (195, (73, 77, 86), '#494D56', '黑')
# (192, (74, 78, 87), '#4A4E57', '黑')
# (180, (92, 94, 107), '#5C5E6B', '灰')
# (176, (89, 91, 104), '#595B68', '灰')
# (173, (78, 82, 91), '#4E525B', '黑')
# (171, (90, 92, 104), '#5A5C68', '灰')
# (169, (86, 90, 102), '#565A66', '灰')
# (168, (77, 81, 90), '#4D515A', '黑')
# (166, (84, 88, 100), '#545864', '灰')
# (166, (79, 83, 92), '#4F535C', '黑')
# (165, (47, 57, 69), '#2F3945', '黑')
# (155, (96, 98, 111), '#60626F', '灰')
# (154, (87, 91, 103), '#575B67', '灰')
# (153, (86, 90, 101), '#565A65', '灰')
# (139, (91, 93, 105), '#5B5D69', '灰')
# (138, (118, 122, 131), '#767A83', '灰')
# (137, (93, 95, 108), '#5D5F6C', '灰')
# (125, (89, 91, 103), '#595B67', '灰')
# (124, (47, 56, 73), '#2F3849', '黑')
# (123, (80, 84, 93), '#50545D', '黑')
# (121, (88, 90, 102), '#585A66', '灰')
# (121, (75, 79, 88), '#4B4F58', '黑')
# (120, (97, 99, 114), '#616372', '灰')
# (120, (85, 89, 100), '#555964', '灰')
# (115, (72, 79, 87), '#484F57', '黑')
# (113, (97, 99, 112), '#616370', '灰')
# (113, (87, 91, 102), '#575B66', '灰')
# (105, (120, 124, 133), '#787C85', '灰')
# (105, (117, 121, 130), '#757982', '灰')
# (103, (45, 57, 71), '#2D3947', '黑')
# (102, (81, 85, 94), '#51555E', '灰')
# (100, (95, 97, 110), '#5F616E', '灰')
# (100, (92, 94, 106), '#5C5E6A', '灰')
# (99, (84, 88, 99), '#545863', '灰')
# (99, (83, 87, 98), '#535762', '灰')
# (98, (78, 83, 89), '#4E5359', '黑')
# (92, (116, 120, 129), '#747881', '灰')
# (92, (93, 97, 109), '#5D616D', '灰')
# (91, (86, 88, 101), '#565865', '灰')
# (91, (48, 56, 69), '#303845', '黑')
# (90, (88, 92, 104), '#585C68', '灰')
# s1: [('黑', 3567), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 14), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (3099, (83, 101, 105), '#536569', '灰')
# (658, (85, 100, 105), '#556469', '灰')
# (589, (82, 101, 105), '#526569', '灰')
# (242, (188, 190, 189), '#BCBEBD', '白')
# (220, (86, 99, 105), '#566369', '灰')
# (204, (187, 189, 188), '#BBBDBC', '白')
# (180, (81, 102, 105), '#516669', '灰')
# (133, (130, 63, 106), '#823F6A', '灰')
# (126, (130, 59, 101), '#823B65', '红')
# (120, (189, 191, 190), '#BDBFBE', '白')
# (104, (190, 192, 191), '#BEC0BF', '白')
# (102, (161, 166, 169), '#A1A6A9', '白')
# (102, (132, 61, 101), '#843D65', '红')
# (100, (169, 173, 174), '#A9ADAE', '白')
# (100, (128, 71, 114), '#804772', '灰')
# (98, (131, 59, 99), '#833B63', '红')
# (98, (92, 97, 117), '#5C6175', '灰')
# (97, (129, 72, 115), '#814873', '灰')
# (96, (132, 60, 100), '#843C64', '红')
# (92, (131, 60, 102), '#833C66', '红')
# (91, (130, 65, 107), '#82416B', '灰')
# (91, (129, 71, 112), '#814770', '灰')
# (91, (129, 64, 106), '#81406A', '灰')
# (91, (83, 100, 107), '#53646B', '灰')
# (90, (163, 168, 171), '#A3A8AB', '白')
# (90, (62, 61, 67), '#3E3D43', '黑')
# (89, (129, 68, 109), '#81446D', '灰')
# (87, (129, 68, 110), '#81446E', '灰')
# (87, (128, 73, 115), '#804973', '灰')
# (85, (129, 66, 109), '#81426D', '灰')
# (82, (82, 101, 107), '#52656B', '灰')
# (79, (128, 70, 111), '#80466F', '灰')
# (78, (133, 58, 99), '#853A63', '红')
# (78, (129, 62, 105), '#813E69', '灰')
# (77, (130, 65, 105), '#824169', '灰')
# (76, (162, 167, 170), '#A2A7AA', '白')
# (75, (133, 61, 101), '#853D65', '红')
# (74, (129, 61, 102), '#813D66', '红')
# (73, (130, 73, 116), '#824974', '灰')
# (72, (186, 188, 187), '#BABCBB', '白')
# (72, (134, 57, 99), '#863963', '红')
# (72, (127, 70, 111), '#7F466F', '灰')
# (71, (131, 84, 128), '#835480', '灰')
# (71, (128, 69, 113), '#804571', '灰')
# (71, (85, 100, 107), '#55646B', '灰')
# s1: [('白', 1110), ('红', 813), ('黑', 90), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 9), ('红', 9), ('黑', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (2512, (26, 38, 54), '#1A2636', '黑')
# (187, (26, 37, 55), '#1A2537', '黑')
# (179, (153, 159, 155), '#999F9B', '白')
# (161, (149, 154, 150), '#959A96', '白')
# (161, (145, 150, 146), '#919692', '灰')
# (157, (31, 36, 32), '#1F2420', '黑')
# (153, (152, 158, 154), '#989E9A', '白')
# (152, (148, 153, 149), '#949995', '白')
# (151, (32, 37, 33), '#202521', '黑')
# (149, (151, 156, 152), '#979C98', '白')
# (141, (150, 155, 151), '#969B97', '白')
# (139, (167, 169, 168), '#A7A9A8', '白')
# (135, (164, 166, 163), '#A4A6A3', '灰')
# (131, (154, 160, 156), '#9AA09C', '白')
# (130, (147, 152, 148), '#939894', '白')
# (127, (151, 157, 153), '#979D99', '白')
# (126, (145, 147, 144), '#919390', '灰')
# (125, (25, 38, 55), '#192637', '黑')
# (124, (33, 38, 34), '#212622', '黑')
# (119, (176, 178, 177), '#B0B2B1', '棕')
# (119, (161, 163, 162), '#A1A3A2', '灰')
# (118, (166, 168, 167), '#A6A8A7', '白')
# (118, (151, 153, 150), '#979996', '白')
# (118, (146, 151, 147), '#929793', '白')
# (117, (149, 151, 148), '#959794', '白')
# (114, (150, 152, 149), '#969895', '白')
# (114, (146, 148, 145), '#929491', '灰')
# (114, (142, 147, 143), '#8E938F', '灰')
# (107, (163, 165, 164), '#A3A5A4', '灰')
# (106, (165, 167, 166), '#A5A7A6', '白')
# (104, (115, 122, 115), '#737A73', '灰')
# (102, (147, 149, 146), '#939592', '灰')
# (99, (173, 175, 174), '#ADAFAE', '棕')
# (96, (164, 166, 165), '#A4A6A5', '白')
# (96, (34, 39, 35), '#222723', '黑')
# (96, (28, 37, 52), '#1C2534', '黑')
# (96, (26, 38, 52), '#1A2634', '黑')
# (95, (163, 165, 162), '#A3A5A2', '灰')
# (95, (141, 146, 142), '#8D928E', '灰')
# (95, (42, 44, 43), '#2A2C2B', '黑')
# (93, (144, 149, 145), '#909591', '灰')
# (93, (30, 35, 31), '#1E231F', '黑')
# (92, (160, 162, 161), '#A0A2A1', '灰')
# (91, (157, 161, 160), '#9DA1A0', '灰')
# (91, (42, 43, 45), '#2A2B2D', '黑')
# s1: [('黑', 3823), ('白', 2249), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 17), ('黑', 12), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (2160, (31, 42, 62), '#1F2A3E', '黑')
# (384, (209, 227, 241), '#D1E3F1', '白')
# (351, (31, 42, 64), '#1F2A40', '黑')
# (338, (31, 42, 60), '#1F2A3C', '黑')
# (332, (210, 228, 242), '#D2E4F2', '白')
# (274, (191, 203, 203), '#BFCBCB', '紫')
# (257, (214, 230, 243), '#D6E6F3', '白')
# (242, (211, 229, 243), '#D3E5F3', '白')
# (241, (216, 233, 243), '#D8E9F3', '白')
# (237, (213, 229, 242), '#D5E5F2', '白')
# (229, (192, 204, 204), '#C0CCCC', '紫')
# (187, (215, 233, 243), '#D7E9F3', '白')
# (184, (193, 205, 205), '#C1CDCD', '紫')
# (168, (217, 234, 244), '#D9EAF4', '白')
# (164, (219, 236, 244), '#DBECF4', '白')
# (163, (212, 228, 241), '#D4E4F1', '白')
# (161, (215, 232, 242), '#D7E8F2', '白')
# (161, (215, 231, 244), '#D7E7F4', '白')
# (144, (212, 230, 242), '#D4E6F2', '白')
# (144, (209, 226, 242), '#D1E2F2', '白')
# (142, (218, 232, 243), '#DAE8F3', '白')
# (132, (218, 235, 243), '#DAEBF3', '白')
# (132, (217, 231, 242), '#D9E7F2', '白')
# (131, (31, 43, 59), '#1F2B3B', '黑')
# (129, (197, 209, 209), '#C5D1D1', '白')
# (126, (194, 206, 206), '#C2CECE', '紫')
# (120, (214, 232, 242), '#D6E8F2', '白')
# (120, (16, 16, 24), '#101018', '黑')
# (118, (31, 41, 66), '#1F2942', '黑')
# (112, (220, 237, 245), '#DCEDF5', '白')
# (111, (206, 223, 239), '#CEDFEF', '灰')
# (111, (196, 208, 208), '#C4D0D0', '紫')
# (108, (214, 228, 241), '#D6E4F1', '白')
# (108, (208, 225, 241), '#D0E1F1', '白')
# (108, (30, 42, 64), '#1E2A40', '黑')
# (106, (208, 226, 240), '#D0E2F0', '白')
# (105, (217, 234, 242), '#D9EAF2', '白')
# (105, (195, 207, 207), '#C3CFCF', '紫')
# (104, (212, 230, 244), '#D4E6F4', '白')
# (104, (30, 43, 62), '#1E2B3E', '黑')
# (102, (218, 235, 245), '#DAEBF5', '白')
# (101, (216, 232, 245), '#D8E8F5', '白')
# (99, (220, 235, 242), '#DCEBF2', '白')
# (99, (220, 234, 243), '#DCEAF3', '白')
# (97, (33, 41, 62), '#21293E', '黑')
# s1: [('白', 4684), ('黑', 3527), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 29), ('黑', 9), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (4125, (34, 50, 76), '#22324C', '红')
# (419, (45, 44, 58), '#2D2C3A', '黑')
# (296, (42, 42, 54), '#2A2A36', '黑')
# (231, (46, 46, 58), '#2E2E3A', '红')
# (228, (43, 40, 57), '#2B2839', '黑')
# (223, (45, 45, 57), '#2D2D39', '黑')
# (217, (44, 43, 57), '#2C2B39', '黑')
# (182, (45, 42, 61), '#2D2A3D', '黑')
# (172, (43, 40, 59), '#2B283B', '黑')
# (171, (45, 42, 59), '#2D2A3B', '黑')
# (159, (46, 46, 56), '#2E2E38', '黑')
# (155, (47, 47, 59), '#2F2F3B', '红')
# (155, (44, 43, 61), '#2C2B3D', '黑')
# (148, (43, 43, 55), '#2B2B37', '黑')
# (146, (53, 56, 65), '#353841', '黑')
# (146, (36, 35, 49), '#242331', '黑')
# (144, (48, 48, 60), '#30303C', '红')
# (143, (44, 41, 58), '#2C293A', '黑')
# (142, (45, 44, 62), '#2D2C3E', '红')
# (141, (44, 43, 59), '#2C2B3B', '黑')
# (135, (38, 37, 51), '#262533', '黑')
# (134, (42, 41, 55), '#2A2937', '黑')
# (133, (42, 39, 56), '#2A2738', '黑')
# (131, (46, 45, 61), '#2E2D3D', '红')
# (130, (35, 34, 48), '#232230', '黑')
# (129, (43, 41, 55), '#2B2937', '黑')
# (128, (47, 46, 62), '#2F2E3E', '红')
# (127, (55, 55, 63), '#37373F', '黑')
# (127, (44, 44, 56), '#2C2C38', '黑')
# (127, (44, 41, 60), '#2C293C', '黑')
# (127, (43, 42, 56), '#2B2A38', '黑')
# (126, (45, 44, 60), '#2D2C3C', '红')
# (121, (39, 38, 52), '#272634', '黑')
# (119, (40, 42, 57), '#282A39', '黑')
# (117, (46, 45, 59), '#2E2D3B', '红')
# (115, (54, 54, 62), '#36363E', '黑')
# (115, (41, 40, 54), '#292836', '黑')
# (114, (45, 45, 55), '#2D2D37', '黑')
# (112, (50, 53, 62), '#32353E', '红')
# (112, (41, 40, 58), '#29283A', '黑')
# (108, (40, 39, 53), '#282735', '黑')
# (108, (37, 36, 50), '#252432', '黑')
# (107, (41, 40, 56), '#292838', '黑')
# (107, (38, 36, 47), '#26242F', '黑')
# (106, (44, 44, 54), '#2C2C36', '黑')
# s1: [('黑', 5347), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 35), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (3023, (23, 32, 39), '#172027', '黑')
# (685, (97, 102, 105), '#616669', '灰')
# (550, (96, 101, 104), '#606568', '灰')
# (454, (98, 103, 106), '#62676A', '灰')
# (333, (97, 101, 102), '#616566', '灰')
# (320, (95, 100, 103), '#5F6467', '灰')
# (274, (95, 99, 100), '#5F6364', '灰')
# (270, (96, 100, 101), '#606465', '灰')
# (256, (23, 24, 28), '#17181C', '黑')
# (251, (21, 22, 27), '#15161B', '黑')
# (250, (100, 105, 108), '#64696C', '灰')
# (238, (94, 99, 102), '#5E6366', '灰')
# (234, (94, 98, 99), '#5E6263', '灰')
# (227, (93, 98, 101), '#5D6265', '灰')
# (215, (22, 23, 27), '#16171B', '黑')
# (205, (99, 104, 107), '#63686B', '灰')
# (202, (24, 25, 29), '#18191D', '黑')
# (192, (22, 23, 28), '#16171C', '黑')
# (192, (20, 21, 26), '#14151A', '黑')
# (181, (21, 22, 26), '#15161A', '黑')
# (180, (25, 26, 30), '#191A1E', '黑')
# (178, (101, 106, 109), '#656A6D', '灰')
# (149, (98, 103, 107), '#62676B', '灰')
# (145, (90, 95, 98), '#5A5F62', '灰')
# (139, (23, 32, 41), '#172029', '黑')
# (138, (98, 102, 103), '#626667', '灰')
# (138, (26, 27, 31), '#1A1B1F', '黑')
# (137, (20, 21, 23), '#141517', '黑')
# (135, (91, 96, 99), '#5B6063', '灰')
# (135, (21, 22, 24), '#151618', '黑')
# (134, (97, 101, 104), '#616568', '灰')
# (134, (23, 32, 37), '#172025', '黑')
# (132, (99, 104, 108), '#63686C', '灰')
# (131, (17, 18, 22), '#111216', '黑')
# (128, (100, 105, 109), '#64696D', '灰')
# (127, (102, 107, 110), '#666B6E', '灰')
# (125, (23, 24, 29), '#17181D', '黑')
# (124, (101, 106, 110), '#656A6E', '灰')
# (122, (22, 23, 25), '#161719', '黑')
# (122, (20, 21, 25), '#141519', '黑')
# (119, (97, 103, 103), '#616767', '灰')
# (119, (27, 28, 32), '#1B1C20', '黑')
# (118, (19, 20, 25), '#131419', '黑')
# (117, (93, 97, 98), '#5D6162', '灰')
# (116, (92, 97, 100), '#5C6164', '灰')
# s1: [('黑', 6112), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 20), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (386, (26, 39, 48), '#1A2730', '黑')
# (217, (26, 39, 47), '#1A272F', '黑')
# (180, (25, 39, 50), '#192732', '黑')
# (175, (28, 38, 48), '#1C2630', '黑')
# (174, (28, 38, 47), '#1C262F', '黑')
# (172, (26, 38, 50), '#1A2632', '黑')
# (109, (25, 39, 48), '#192730', '黑')
# (90, (81, 83, 78), '#51534E', '红')
# (84, (82, 84, 79), '#52544F', '黑')
# (70, (90, 92, 89), '#5A5C59', '灰')
# (60, (82, 85, 78), '#52554E', '红')
# (58, (91, 93, 90), '#5B5D5A', '灰')
# (55, (75, 77, 74), '#4B4D4A', '黑')
# (55, (26, 39, 45), '#1A272D', '黑')
# (53, (160, 179, 185), '#A0B3B9', '棕')
# (53, (81, 84, 77), '#51544D', '红')
# (50, (159, 178, 184), '#9FB2B8', '棕')
# (49, (79, 81, 76), '#4F514C', '黑')
# (49, (28, 38, 50), '#1C2632', '黑')
# (48, (161, 178, 186), '#A1B2BA', '棕')
# (48, (25, 40, 47), '#19282F', '黑')
# (46, (78, 80, 75), '#4E504B', '黑')
# (45, (162, 179, 187), '#A2B3BB', '棕')
# (45, (90, 91, 93), '#5A5B5D', '灰')
# (45, (89, 89, 89), '#595959', '灰')
# (44, (161, 178, 188), '#A1B2BC', '棕')
# (44, (91, 96, 92), '#5B605C', '灰')
# (43, (137, 154, 161), '#899AA1', '白')
# (43, (92, 94, 91), '#5C5E5B', '灰')
# (43, (89, 90, 92), '#595A5C', '灰')
# (43, (25, 39, 52), '#192734', '黑')
# (42, (88, 90, 87), '#585A57', '灰')
# (42, (76, 78, 75), '#4C4E4B', '黑')
# (40, (81, 83, 80), '#515350', '黑')
# (40, (77, 79, 74), '#4D4F4A', '黑')
# (39, (162, 179, 189), '#A2B3BD', '棕')
# (39, (159, 178, 185), '#9FB2B9', '棕')
# (39, (158, 177, 184), '#9EB1B8', '棕')
# (39, (134, 152, 156), '#86989C', '灰')
# (39, (90, 92, 87), '#5A5C57', '灰')
# (38, (91, 96, 90), '#5B605A', '灰')
# (38, (89, 89, 91), '#59595B', '灰')
# (37, (89, 89, 87), '#595957', '灰')
# (37, (82, 84, 81), '#525451', '黑')
# (37, (77, 79, 76), '#4D4F4C', '黑')
# s1: [('黑', 2038), ('红', 203), ('白', 43), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 20), ('红', 3), ('白', 1), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (1125, (28, 48, 75), '#1C304B', '红')
# (106, (30, 47, 75), '#1E2F4B', '红')
# (99, (28, 47, 77), '#1C2F4D', '红')
# (92, (30, 47, 77), '#1E2F4D', '红')
# (82, (30, 47, 73), '#1E2F49', '红')
# (67, (28, 48, 73), '#1C3049', '红')
# (56, (27, 48, 77), '#1B304D', '红')
# (55, (37, 36, 41), '#252429', '黑')
# (55, (27, 49, 73), '#1B3149', '红')
# (50, (38, 37, 42), '#26252A', '黑')
# (50, (36, 36, 38), '#242426', '黑')
# (48, (27, 48, 75), '#1B304B', '红')
# (45, (36, 35, 40), '#242328', '黑')
# (45, (35, 35, 35), '#232323', '黑')
# (42, (25, 49, 77), '#19314D', '红')
# (42, (25, 49, 73), '#193149', '黑')
# (40, (39, 37, 40), '#272528', '黑')
# (40, (35, 35, 37), '#232325', '黑')
# (38, (72, 19, 27), '#48131B', '红')
# (36, (72, 23, 27), '#48171B', '红')
# (36, (34, 35, 37), '#222325', '黑')
# (36, (25, 49, 75), '#19314B', '红')
# (35, (71, 20, 27), '#47141B', '红')
# (35, (36, 36, 36), '#242424', '黑')
# (34, (35, 36, 38), '#232426', '黑')
# (34, (34, 34, 36), '#222224', '黑')
# (34, (34, 34, 34), '#222222', '黑')
# (34, (33, 33, 35), '#212123', '黑')
# (34, (31, 46, 77), '#1F2E4D', '红')
# (33, (40, 39, 44), '#28272C', '黑')
# (33, (35, 34, 40), '#232228', '黑')
# (33, (35, 34, 39), '#232227', '黑')
# (31, (74, 23, 30), '#4A171E', '黑')
# (30, (73, 24, 30), '#49181E', '黑')
# (30, (73, 23, 32), '#491720', '黑')
# (30, (27, 48, 79), '#1B304F', '红')
# (29, (73, 24, 28), '#49181C', '黑')
# (29, (71, 24, 30), '#47181E', '黑')
# (29, (55, 18, 25), '#371219', '黑')
# (29, (36, 37, 39), '#242527', '黑')
# (29, (33, 33, 33), '#212121', '黑')
# (28, (71, 22, 26), '#47161A', '红')
# (28, (38, 38, 40), '#262628', '黑')
# (28, (28, 48, 72), '#1C3048', '黑')
# (27, (86, 27, 31), '#561B1F', '红')
# s1: [('黑', 965), ('红', 164), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 27), ('红', 5), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (2846, (17, 23, 35), '#111723', '黑')
# (839, (19, 23, 26), '#13171A', '黑')
# (555, (16, 20, 23), '#101417', '黑')
# (539, (18, 22, 25), '#121619', '黑')
# (449, (17, 21, 24), '#111518', '黑')
# (427, (15, 19, 22), '#0F1316', '黑')
# (340, (18, 19, 23), '#121317', '黑')
# (292, (23, 28, 34), '#171C22', '黑')
# (289, (24, 29, 33), '#181D21', '黑')
# (276, (19, 24, 27), '#13181B', '黑')
# (269, (20, 24, 27), '#14181B', '黑')
# (264, (22, 27, 33), '#161B21', '黑')
# (255, (17, 23, 37), '#111725', '黑')
# (254, (21, 26, 30), '#151A1E', '黑')
# (245, (17, 24, 34), '#111822', '黑')
# (240, (24, 29, 35), '#181D23', '黑')
# (234, (21, 24, 29), '#15181D', '黑')
# (226, (19, 24, 28), '#13181C', '黑')
# (221, (20, 25, 29), '#14191D', '黑')
# (219, (22, 27, 31), '#161B1F', '黑')
# (217, (22, 25, 30), '#16191E', '黑')
# (217, (14, 18, 21), '#0E1215', '黑')
# (213, (21, 25, 28), '#15191C', '黑')
# (201, (23, 28, 32), '#171C20', '黑')
# (188, (18, 23, 26), '#12171A', '黑')
# (185, (20, 23, 28), '#14171C', '黑')
# (181, (21, 26, 32), '#151A20', '黑')
# (169, (22, 26, 29), '#161A1D', '黑')
# (151, (19, 22, 27), '#13161B', '黑')
# (151, (18, 23, 27), '#12171B', '黑')
# (139, (25, 30, 34), '#191E22', '黑')
# (133, (23, 30, 36), '#171E24', '黑')
# (129, (17, 24, 32), '#111820', '黑')
# (126, (25, 30, 36), '#191E24', '黑')
# (126, (18, 19, 21), '#121315', '黑')
# (122, (23, 26, 31), '#171A1F', '黑')
# (119, (16, 23, 31), '#10171F', '黑')
# (118, (16, 24, 37), '#101825', '黑')
# (115, (19, 20, 24), '#131418', '黑')
# (110, (17, 22, 26), '#11161A', '黑')
# (108, (18, 25, 33), '#121921', '黑')
# (107, (19, 26, 34), '#131A22', '黑')
# (103, (21, 28, 38), '#151C26', '黑')
# (100, (20, 25, 31), '#14191F', '黑')
# (99, (19, 24, 30), '#13181E', '黑')
# s1: [('黑', 12906), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 45), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (2869, (45, 61, 51), '#2D3D33', '红')
# (719, (54, 55, 59), '#36373B', '黑')
# (409, (55, 56, 60), '#37383C', '黑')
# (383, (47, 60, 51), '#2F3C33', '红')
# (383, (44, 61, 51), '#2C3D33', '红')
# (292, (53, 54, 58), '#35363A', '红')
# (287, (93, 45, 59), '#5D2D3B', '黑')
# (279, (54, 55, 57), '#363739', '红')
# (269, (94, 46, 60), '#5E2E3C', '黑')
# (264, (62, 63, 65), '#3E3F41', '黑')
# (250, (61, 62, 64), '#3D3E40', '黑')
# (239, (53, 54, 56), '#353638', '红')
# (211, (52, 53, 55), '#343537', '红')
# (208, (51, 52, 54), '#333436', '红')
# (203, (60, 61, 63), '#3C3D3F', '黑')
# (185, (50, 51, 53), '#323335', '红')
# (180, (139, 65, 98), '#8B4162', '灰')
# (176, (49, 50, 52), '#313234', '红')
# (171, (52, 53, 57), '#343539', '红')
# (164, (55, 56, 58), '#37383A', '黑')
# (152, (138, 64, 97), '#8A4061', '红')
# (149, (59, 60, 62), '#3B3C3E', '黑')
# (144, (93, 47, 60), '#5D2F3C', '黑')
# (143, (102, 41, 59), '#66293B', '黑')
# (143, (48, 49, 51), '#303133', '黑')
# (139, (95, 47, 61), '#5F2F3D', '黑')
# (139, (47, 48, 50), '#2F3032', '黑')
# (132, (56, 57, 59), '#38393B', '黑')
# (129, (44, 62, 50), '#2C3E32', '红')
# (128, (94, 48, 61), '#5E303D', '黑')
# (127, (46, 47, 49), '#2E2F31', '黑')
# (121, (96, 43, 59), '#602B3B', '黑')
# (119, (103, 40, 59), '#67283B', '黑')
# (117, (56, 57, 61), '#38393D', '黑')
# (116, (137, 63, 96), '#893F60', '红')
# (114, (137, 62, 93), '#893E5D', '红')
# (114, (95, 44, 59), '#5F2C3B', '黑')
# (114, (57, 58, 60), '#393A3C', '黑')
# (111, (58, 59, 61), '#3A3B3D', '黑')
# (106, (63, 64, 66), '#3F4042', '黑')
# (105, (44, 61, 53), '#2C3D35', '红')
# (103, (92, 46, 59), '#5C2E3B', '黑')
# (102, (45, 46, 48), '#2D2E30', '黑')
# (96, (92, 48, 61), '#5C303D', '黑')
# (95, (44, 45, 47), '#2C2D2F', '黑')
# s1: [('黑', 5007), ('红', 382), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 28), ('红', 3), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (3776, (50, 72, 95), '#32485F', '黑')
# (363, (61, 74, 91), '#3D4A5B', '黑')
# (251, (62, 73, 91), '#3E495B', '黑')
# (245, (63, 74, 92), '#3F4A5C', '黑')
# (213, (62, 75, 92), '#3E4B5C', '黑')
# (209, (61, 72, 90), '#3D485A', '黑')
# (145, (60, 71, 89), '#3C4759', '黑')
# (142, (66, 77, 97), '#424D61', '黑')
# (130, (67, 78, 98), '#434E62', '黑')
# (128, (51, 71, 95), '#33475F', '黑')
# (127, (59, 75, 91), '#3B4B5B', '黑')
# (121, (48, 73, 95), '#30495F', '黑')
# (117, (67, 74, 80), '#434A50', '黑')
# (117, (65, 76, 96), '#414C60', '黑')
# (117, (65, 72, 78), '#41484E', '黑')
# (112, (66, 73, 79), '#42494F', '黑')
# (111, (65, 76, 94), '#414C5E', '黑')
# (109, (50, 72, 96), '#324860', '黑')
# (106, (62, 69, 79), '#3E454F', '黑')
# (105, (61, 68, 78), '#3D444E', '黑')
# (105, (59, 70, 88), '#3B4658', '黑')
# (103, (64, 75, 93), '#404B5D', '黑')
# (99, (63, 76, 93), '#3F4C5D', '黑')
# (99, (63, 70, 80), '#3F4650', '黑')
# (99, (51, 59, 70), '#333B46', '黑')
# (99, (50, 72, 93), '#32485D', '黑')
# (98, (52, 58, 70), '#343A46', '黑')
# (96, (60, 67, 77), '#3C434D', '黑')
# (96, (52, 59, 69), '#343B45', '黑')
# (94, (52, 60, 71), '#343C47', '黑')
# (92, (68, 75, 81), '#444B51', '黑')
# (92, (53, 62, 71), '#353E47', '黑')
# (89, (60, 66, 78), '#3C424E', '黑')
# (88, (66, 77, 95), '#424D5F', '黑')
# (88, (66, 73, 81), '#424951', '黑')
# (88, (64, 71, 77), '#40474D', '黑')
# (88, (49, 55, 67), '#313743', '黑')
# (87, (62, 75, 94), '#3E4B5E', '黑')
# (86, (48, 54, 66), '#303642', '黑')
# (85, (59, 66, 76), '#3B424C', '黑')
# (84, (68, 79, 99), '#444F63', '黑')
# (84, (53, 61, 72), '#353D48', '黑')
# (83, (70, 77, 83), '#464D53', '黑')
# (83, (59, 65, 77), '#3B414D', '黑')
# (81, (63, 70, 78), '#3F464E', '黑')
# s1: [('黑', 9030), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 45), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (3133, (52, 58, 92), '#343A5C', '黑')
# (146, (119, 119, 131), '#777783', '灰')
# (141, (109, 109, 121), '#6D6D79', '灰')
# (128, (120, 120, 132), '#787884', '灰')
# (128, (113, 113, 125), '#71717D', '灰')
# (125, (124, 124, 134), '#7C7C86', '灰')
# (117, (60, 61, 63), '#3C3D3F', '黑')
# (115, (116, 115, 129), '#747381', '灰')
# (115, (52, 58, 90), '#343A5A', '黑')
# (111, (121, 120, 134), '#797886', '灰')
# (110, (111, 111, 123), '#6F6F7B', '灰')
# (109, (110, 110, 122), '#6E6E7A', '灰')
# (108, (122, 122, 132), '#7A7A84', '灰')
# (107, (59, 60, 62), '#3B3C3E', '黑')
# (102, (118, 118, 130), '#767682', '灰')
# (102, (114, 114, 126), '#72727E', '灰')
# (101, (116, 116, 126), '#74747E', '灰')
# (100, (123, 123, 133), '#7B7B85', '灰')
# (100, (117, 117, 129), '#757581', '灰')
# (97, (123, 123, 135), '#7B7B87', '灰')
# (97, (121, 121, 131), '#797983', '灰')
# (97, (114, 113, 127), '#72717F', '灰')
# (96, (108, 108, 120), '#6C6C78', '灰')
# (94, (124, 124, 136), '#7C7C88', '灰')
# (94, (124, 122, 135), '#7C7A87', '灰')
# (93, (115, 115, 125), '#73737D', '灰')
# (93, (57, 52, 56), '#393438', '红')
# (91, (61, 63, 62), '#3D3F3E', '黑')
# (90, (111, 111, 121), '#6F6F79', '灰')
# (89, (118, 118, 128), '#767680', '灰')
# (88, (113, 113, 123), '#71717B', '灰')
# (88, (52, 58, 94), '#343A5E', '黑')
# (87, (135, 135, 145), '#878791', '灰')
# (87, (111, 110, 124), '#6F6E7C', '灰')
# (87, (61, 62, 64), '#3D3E40', '黑')
# (85, (120, 119, 133), '#787785', '灰')
# (85, (112, 112, 124), '#70707C', '灰')
# (84, (117, 116, 130), '#757482', '灰')
# (84, (46, 46, 48), '#2E2E30', '黑')
# (83, (125, 125, 135), '#7D7D87', '灰')
# (83, (120, 120, 130), '#787882', '灰')
# (83, (47, 46, 51), '#2F2E33', '黑')
# (82, (118, 117, 131), '#767583', '灰')
# (82, (115, 115, 127), '#73737F', '灰')
# (82, (47, 48, 52), '#2F3034', '黑')
# s1: [('黑', 3987), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 10), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (4113, (31, 36, 58), '#1F243A', '黑')
# (1569, (9, 11, 10), '#090B0A', '黑')
# (1365, (10, 12, 11), '#0A0C0B', '黑')
# (1330, (8, 10, 9), '#080A09', '黑')
# (1314, (7, 9, 8), '#070908', '黑')
# (1011, (11, 13, 12), '#0B0D0C', '黑')
# (830, (12, 14, 13), '#0C0E0D', '黑')
# (585, (13, 15, 14), '#0D0F0E', '黑')
# (523, (14, 16, 15), '#0E100F', '黑')
# (430, (6, 8, 7), '#060807', '黑')
# (388, (15, 17, 16), '#0F1110', '黑')
# (374, (16, 18, 17), '#101211', '黑')
# (352, (18, 20, 19), '#121413', '黑')
# (341, (17, 19, 18), '#111312', '黑')
# (302, (19, 21, 20), '#131514', '黑')
# (282, (10, 11, 13), '#0A0B0D', '黑')
# (275, (104, 106, 105), '#686A69', '灰')
# (271, (103, 105, 104), '#676968', '灰')
# (261, (20, 22, 21), '#141615', '黑')
# (251, (12, 13, 15), '#0C0D0F', '黑')
# (250, (105, 107, 106), '#696B6A', '灰')
# (245, (11, 12, 14), '#0B0C0E', '黑')
# (238, (21, 23, 22), '#151716', '黑')
# (234, (9, 10, 12), '#090A0C', '黑')
# (208, (102, 104, 103), '#666867', '灰')
# (203, (13, 14, 16), '#0D0E10', '黑')
# (195, (22, 24, 23), '#161817', '黑')
# (190, (106, 108, 107), '#6A6C6B', '灰')
# (172, (8, 9, 11), '#08090B', '黑')
# (171, (101, 103, 102), '#656766', '灰')
# (168, (9, 11, 8), '#090B08', '黑')
# (165, (14, 15, 17), '#0E0F11', '黑')
# (149, (8, 10, 7), '#080A07', '黑')
# (146, (5, 7, 6), '#050706', '黑')
# (144, (23, 25, 24), '#171918', '黑')
# (126, (99, 101, 98), '#636562', '灰')
# (115, (7, 8, 10), '#07080A', '黑')
# (113, (101, 103, 100), '#656764', '灰')
# (111, (100, 102, 101), '#646665', '灰')
# (111, (24, 26, 25), '#181A19', '黑')
# (108, (103, 105, 102), '#676966', '灰')
# (104, (4, 6, 5), '#040605', '黑')
# (100, (102, 104, 101), '#666865', '灰')
# (98, (100, 102, 99), '#646663', '灰')
# (97, (107, 109, 108), '#6B6D6C', '灰')
# s1: [('黑', 18010), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 32), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (2465, (46, 91, 110), '#2E5B6E', '黑')
# (427, (45, 92, 110), '#2D5C6E', '黑')
# (314, (48, 91, 110), '#305B6E', '黑')
# (193, (90, 98, 109), '#5A626D', '灰')
# (172, (46, 91, 112), '#2E5B70', '黑')
# (167, (89, 99, 108), '#59636C', '灰')
# (166, (46, 92, 108), '#2E5C6C', '黑')
# (165, (45, 92, 112), '#2D5C70', '黑')
# (158, (9, 9, 11), '#09090B', '黑')
# (152, (48, 90, 112), '#305A70', '黑')
# (150, (89, 99, 109), '#59636D', '灰')
# (136, (90, 100, 110), '#5A646E', '灰')
# (127, (90, 100, 109), '#5A646D', '灰')
# (123, (90, 99, 108), '#5A636C', '灰')
# (117, (8, 8, 10), '#08080A', '黑')
# (114, (10, 10, 12), '#0A0A0C', '黑')
# (112, (48, 91, 108), '#305B6C', '黑')
# (105, (87, 100, 109), '#57646D', '灰')
# (105, (8, 7, 12), '#08070C', '黑')
# (101, (88, 101, 110), '#58656E', '灰')
# (100, (89, 98, 107), '#59626B', '灰')
# (100, (88, 101, 109), '#58656D', '灰')
# (98, (91, 98, 108), '#5B626C', '灰')
# (98, (9, 9, 9), '#090909', '黑')
# (95, (91, 99, 110), '#5B636E', '灰')
# (95, (90, 103, 112), '#5A6770', '灰')
# (95, (7, 7, 9), '#070709', '黑')
# (94, (9, 7, 10), '#09070A', '黑')
# (91, (89, 103, 114), '#596772', '灰')
# (90, (91, 95, 106), '#5B5F6A', '灰')
# (88, (10, 8, 11), '#0A080B', '黑')
# (86, (9, 7, 12), '#09070C', '黑')
# (86, (8, 9, 13), '#08090D', '黑')
# (85, (7, 8, 10), '#07080A', '黑')
# (80, (10, 10, 10), '#0A0A0A', '黑')
# (80, (8, 9, 11), '#08090B', '黑')
# (78, (89, 102, 111), '#59666F', '灰')
# (78, (87, 100, 106), '#57646A', '灰')
# (78, (8, 8, 8), '#080808', '黑')
# (78, (7, 6, 11), '#07060B', '黑')
# (77, (91, 100, 109), '#5B646D', '灰')
# (77, (90, 102, 114), '#5A6672', '灰')
# (74, (45, 92, 108), '#2D5C6C', '黑')
# (74, (11, 9, 10), '#0B090A', '黑')
# (73, (9, 8, 13), '#09080D', '黑')
# s1: [('黑', 5636), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 26), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (3584, (52, 85, 102), '#345566', '黑')
# (217, (73, 80, 108), '#49506C', '灰')
# (212, (63, 68, 88), '#3F4458', '黑')
# (179, (64, 69, 89), '#404559', '黑')
# (177, (74, 81, 109), '#4A516D', '灰')
# (174, (72, 79, 107), '#484F6B', '黑')
# (171, (61, 66, 86), '#3D4256', '黑')
# (168, (71, 78, 106), '#474E6A', '黑')
# (164, (75, 82, 110), '#4B526E', '灰')
# (145, (62, 67, 87), '#3E4357', '黑')
# (141, (68, 73, 95), '#44495F', '黑')
# (139, (69, 74, 96), '#454A60', '黑')
# (134, (70, 77, 105), '#464D69', '黑')
# (134, (68, 75, 103), '#444B67', '黑')
# (134, (65, 71, 93), '#41475D', '黑')
# (133, (77, 86, 115), '#4D5673', '灰')
# (121, (67, 72, 94), '#43485E', '黑')
# (117, (76, 85, 114), '#4C5572', '灰')
# (117, (69, 76, 104), '#454C68', '黑')
# (112, (64, 69, 91), '#40455B', '黑')
# (108, (62, 67, 89), '#3E4359', '黑')
# (108, (61, 66, 88), '#3D4258', '黑')
# (107, (77, 88, 116), '#4D5874', '灰')
# (104, (60, 65, 85), '#3C4155', '黑')
# (97, (75, 84, 113), '#4B5471', '灰')
# (96, (68, 76, 99), '#444C63', '黑')
# (96, (66, 72, 96), '#424860', '黑')
# (95, (67, 74, 100), '#434A64', '黑')
# (95, (65, 70, 92), '#41465C', '黑')
# (95, (63, 68, 90), '#3F445A', '黑')
# (94, (78, 89, 117), '#4E5975', '灰')
# (94, (67, 75, 98), '#434B62', '黑')
# (93, (68, 74, 98), '#444A62', '黑')
# (93, (65, 71, 95), '#41475F', '黑')
# (93, (63, 69, 91), '#3F455B', '黑')
# (92, (65, 70, 90), '#41465A', '黑')
# (91, (79, 90, 118), '#4F5A76', '灰')
# (91, (63, 68, 87), '#3F4457', '黑')
# (90, (76, 83, 111), '#4C536F', '灰')
# (90, (67, 73, 97), '#434961', '黑')
# (90, (66, 72, 94), '#42485E', '黑')
# (90, (60, 65, 87), '#3C4157', '黑')
# (88, (70, 77, 103), '#464D67', '黑')
# (87, (69, 76, 102), '#454C66', '黑')
# (87, (68, 75, 101), '#444B65', '黑')
# s1: [('黑', 7550), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 35), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑
# (1801, (30, 66, 98), '#1E4262', '黑')
# (186, (28, 67, 98), '#1C4362', '黑')
# (141, (31, 66, 98), '#1F4262', '黑')
# (130, (30, 66, 100), '#1E4264', '黑')
# (105, (30, 67, 96), '#1E4360', '黑')
# (83, (28, 67, 100), '#1C4364', '黑')
# (80, (31, 66, 96), '#1F4260', '黑')
# (76, (28, 67, 96), '#1C4360', '黑')
# (63, (31, 65, 100), '#1F4164', '黑')
# (53, (27, 68, 98), '#1B4462', '黑')
# (43, (28, 66, 102), '#1C4266', '黑')
# (39, (25, 69, 98), '#194562', '黑')
# (32, (32, 65, 98), '#204162', '黑')
# (27, (32, 65, 100), '#204164', '黑')
# (22, (27, 68, 96), '#1B4460', '黑')
# (21, (30, 66, 102), '#1E4266', '黑')
# (18, (27, 68, 100), '#1B4464', '黑')
# (17, (31, 65, 102), '#1F4166', '黑')
# (16, (32, 65, 96), '#204160', '黑')
# (16, (31, 66, 94), '#1F425E', '黑')
# (15, (75, 23, 62), '#4B173E', '红')
# (14, (77, 25, 64), '#4D1940', '红')
# (14, (34, 64, 98), '#224062', '黑')
# (13, (76, 28, 66), '#4C1C42', '黑')
# (13, (30, 67, 94), '#1E435E', '黑')
# (12, (82, 30, 68), '#521E44', '黑')
# (12, (81, 20, 64), '#511440', '红')
# (12, (77, 27, 65), '#4D1B41', '黑')
# (12, (76, 24, 63), '#4C183F', '红')
# (12, (72, 24, 62), '#48183E', '红')
# (12, (34, 64, 100), '#224064', '黑')
# (12, (32, 64, 102), '#204066', '黑')
# (12, (28, 68, 94), '#1C445E', '黑')
# (11, (87, 27, 65), '#571B41', '黑')
# (11, (83, 28, 68), '#531C44', '黑')
# (11, (82, 30, 69), '#521E45', '黑')
# (11, (80, 29, 70), '#501D46', '黑')
# (11, (79, 29, 67), '#4F1D43', '黑')
# (11, (79, 28, 69), '#4F1C45', '黑')
# (11, (78, 23, 62), '#4E173E', '红')
# (11, (77, 26, 67), '#4D1A43', '黑')
# (11, (76, 25, 66), '#4C1942', '红')
# (11, (76, 21, 63), '#4C153F', '红')
# (11, (75, 25, 63), '#4B193F', '红')
# (11, (73, 25, 63), '#49193F', '红')
# s1: [('黑', 3146), ('红', 120), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 35), ('红', 10), ('白', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 红
# (4781, (33, 54, 83), '#213653', '黑')
# (443, (234, 240, 240), '#EAF0F0', '白')
# (440, (205, 218, 224), '#CDDAE0', '白')
# (424, (229, 238, 237), '#E5EEED', '白')
# (406, (203, 218, 225), '#CBDAE1', '白')
# (393, (240, 242, 241), '#F0F2F1', '白')
# (393, (190, 201, 203), '#BEC9CB', '紫')
# (376, (233, 239, 239), '#E9EFEF', '白')
# (362, (236, 240, 241), '#ECF0F1', '白')
# (347, (203, 216, 222), '#CBD8DE', '白')
# (335, (206, 219, 225), '#CEDBE1', '红')
# (326, (197, 210, 216), '#C5D2D8', '白')
# (325, (204, 217, 223), '#CCD9DF', '白')
# (298, (205, 220, 227), '#CDDCE3', '红')
# (296, (204, 219, 226), '#CCDBE2', '红')
# (278, (230, 239, 238), '#E6EFEE', '白')
# (272, (194, 208, 211), '#C2D0D3', '白')
# (259, (6, 8, 7), '#060807', '黑')
# (253, (228, 237, 236), '#E4EDEC', '白')
# (245, (214, 228, 231), '#D6E4E7', '白')
# (238, (193, 207, 210), '#C1CFD2', '紫')
# (229, (191, 202, 204), '#BFCACC', '紫')
# (229, (189, 200, 202), '#BDC8CA', '紫')
# (227, (215, 229, 232), '#D7E5E8', '白')
# (226, (5, 7, 6), '#050706', '黑')
# (223, (200, 213, 219), '#C8D5DB', '白')
# (219, (196, 209, 215), '#C4D1D7', '白')
# (211, (3, 5, 4), '#030504', '黑')
# (210, (213, 226, 232), '#D5E2E8', '灰')
# (210, (199, 212, 218), '#C7D4DA', '红')
# (206, (195, 209, 212), '#C3D1D4', '白')
# (204, (190, 204, 205), '#BECCCD', '紫')
# (203, (167, 181, 184), '#A7B5B8', '棕')
# (201, (198, 211, 217), '#C6D3D9', '白')
# (197, (202, 215, 221), '#CAD7DD', '白')
# (196, (213, 227, 230), '#D5E3E6', '灰')
# (195, (201, 214, 220), '#C9D6DC', '白')
# (193, (202, 217, 224), '#CAD9E0', '白')
# (193, (192, 206, 209), '#C0CED1', '紫')
# (192, (237, 241, 240), '#EDF1F0', '白')
# (191, (188, 199, 201), '#BCC7C9', '白')
# (189, (231, 240, 239), '#E7F0EF', '白')
# (188, (191, 205, 208), '#BFCDD0', '紫')
# (185, (212, 225, 231), '#D4E1E7', '灰')
# (183, (208, 221, 227), '#D0DDE3', '红')
# s1: [('白', 7123), ('黑', 5477), ('红', 1322), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 25), ('红', 5), ('黑', 4), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
# (978, (48, 52, 63), '#30343F', '红')
# (412, (48, 52, 64), '#303440', '红')
# (370, (48, 52, 61), '#30343D', '红')
# (165, (195, 197, 186), '#C3C5BA', '白')
# (162, (212, 214, 201), '#D4D6C9', '红')
# (157, (194, 196, 185), '#C2C4B9', '白')
# (147, (196, 198, 187), '#C4C6BB', '白')
# (132, (46, 53, 63), '#2E353F', '红')
# (124, (200, 200, 192), '#C8C8C0', '紫')
# (113, (210, 212, 199), '#D2D4C7', '白')
# (113, (197, 198, 190), '#C5C6BE', '白')
# (112, (49, 51, 63), '#31333F', '红')
# (109, (187, 191, 177), '#BBBFB1', '棕')
# (108, (211, 213, 200), '#D3D5C8', '白')
# (99, (193, 195, 184), '#C1C3B8', '白')
# (98, (206, 208, 195), '#CED0C3', '灰')
# (97, (209, 211, 198), '#D1D3C6', '白')
# (96, (46, 52, 64), '#2E3440', '红')
# (91, (133, 135, 134), '#858786', '灰')
# (90, (208, 210, 197), '#D0D2C5', '灰')
# (90, (198, 199, 191), '#C6C7BF', '白')
# (90, (134, 136, 135), '#868887', '灰')
# (90, (131, 133, 132), '#838584', '灰')
# (89, (213, 215, 202), '#D5D7CA', '红')
# (89, (196, 198, 185), '#C4C6B9', '白')
# (88, (46, 53, 61), '#2E353D', '红')
# (87, (132, 134, 133), '#848685', '灰')
# (86, (192, 196, 182), '#C0C4B6', '白')
# (85, (207, 209, 196), '#CFD1C4', '灰')
# (85, (196, 197, 189), '#C4C5BD', '白')
# (85, (188, 192, 178), '#BCC0B2', '棕')
# (84, (203, 203, 195), '#CBCBC3', '紫')
# (83, (193, 197, 183), '#C1C5B7', '白')
# (82, (199, 199, 191), '#C7C7BF', '白')
# (81, (92, 92, 104), '#5C5C68', '灰')
# (80, (205, 205, 197), '#CDCDC5', '灰')
# (80, (192, 194, 183), '#C0C2B7', '白')
# (79, (204, 204, 196), '#CCCCC4', '紫')
# (78, (202, 202, 194), '#CACAC2', '紫')
# (77, (201, 201, 193), '#C9C9C1', '紫')
# (77, (195, 197, 184), '#C3C5B8', '白')
# (76, (189, 193, 179), '#BDC1B3', '白')
# (75, (212, 212, 202), '#D4D4CA', '白')
# (74, (205, 207, 194), '#CDCFC2', '灰')
# (73, (203, 204, 196), '#CBCCC4', '紫')
# s1: [('白', 1822), ('红', 251), ('黑', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('白', 18), ('红', 2), ('黑', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 白
