# %%
from PIL import Image
import sys
import os
import cmath
path='/root/a_lilei/data/test4/白80.jpg_黑48.jpg'
image = Image.open(path)
a= image.getcolors(555555)
b=sorted(a,reverse=True)
count =0
f = open('/root/a_lilei/test2/color.txt').readlines()
rgb = {}
for i in f :
    s=i.replace("\n",'').split("\t")
    rgb[s[2]]=s[-1]
def color(value):
    digit = list(map(str, range(10))) + list("ABCDEF")
    if isinstance(value, tuple):
        string = '#'
        for i in value:
            a1 = i // 16
            a2 = i % 16
            string += digit[a1] + digit[a2]
        return string
    elif isinstance(value, str):
        a1 = digit.index(value[1]) * 16 + digit.index(value[2])
        a2 = digit.index(value[3]) * 16 + digit.index(value[4])
        a3 = digit.index(value[5]) * 16 + digit.index(value[6])
        return (a1, a2, a3)     
hei=0
bai=0
hong=0
lan=0
hui=0
ying=0
black=0
white=0
red=0
blue=0
gray=0
silvery=0
k=0
bai1=0
bai2=0
white1=0
white2=0
Y=0
for i in b :
    result = {}
    rgbsum = i[1][0]+i[1][1]+i[1][2]
    minn = -1
    for r1 in rgb :
        s1= list(map(int ,r1.split(',')))  
        rgb1=abs(i[1][0]-s1[0])
        rgb2=abs(i[1][1]-s1[1])
        rgb3=abs(i[1][2]-s1[2])
        if rgb1 <60 and rgb2 < 60 and rgb3 <60 :
            rgbsum2 = abs(s1[0]+s1[1]+s1[2] - rgbsum)
            result[rgbsum2]=rgb[r1]
            if minn == -1:
                minn = rgbsum2
            else :
                if minn > rgbsum2:
                    minn = rgbsum2
    print((i[0],i[1],color((i[1])),result[minn]))
    count+=1      
    #-------------------测试三--------------------------------------------------
    if result[minn]=='黑'or (result[minn]=='玫瑰棕色'and i[1][0]<178)or (result[minn]=='灰黑'and i[1][0]<50)or(result[minn]=='深黑' and i[1][0]<80):
        black=black+i[0]
    if result[minn]=='白':
        white2=white2+i[0]
    if result[minn]=='雪':
        white1=white1+i[0]
    if (result[minn]=='红')or (result[minn]=='玫瑰棕色'and i[1][0]>=178)or(result[minn]=='马鞍棕色' and i[1][0]>90) or (result[minn]=='灰黑' and i[1][0]>60 and i[1][1]<45) or(result[minn]=='深黑' and i[1][0]>80) or(result[minn]=='浅石板灰' and i[1][0]>165)or(result[minn]=='暗淡的灰'and i[1][0]>=120):
        red=red+i[0]
    data1=[('黑',black),('白',white),('红',red),('蓝',blue),('灰',gray),('银',silvery)]
    s1=sorted(data1,key=lambda x:x[1],reverse=True)
    if result[minn]=='黑'or (result[minn]=='玫瑰棕色' and i[1][0]<178)or (result[minn]=='灰黑'and i[1][0]<50)or(result[minn]=='深黑' and i[1][0]<80):
        hei+=1
    if result[minn]=='白':
        bai1+=1
    if result[minn]=='雪':
        bai2+=1
    if (result[minn]=='红')or (result[minn]=='马鞍棕色' and i[1][0]>90)or (result[minn]=='灰黑' and i[1][0]>60 and i[1][1]<45)or(result[minn]=='深黑' and i[1][0]>80)or(result[minn]=='浅石板灰' and i[1][0]>=165)or (result[minn]=='暗淡的灰'and i[1][0]>=120)or(result[minn]=='玫瑰棕色' and i[1][0]>=178):
        hong+=1
    white=white1+white2
    bai=bai1+bai2
    data2=[('黑',hei),('白',bai),('红',hong),('蓝',lan),('灰',hui),('银',ying)]
    s2=sorted(data2,key=lambda x:x[1],reverse=True)
    name=path.split('/')[-1][0]
    if count==15:
        data_1=s1
        data_2=s2
    if count==45:
        k=abs(data2[0][1]-data2[1][1])
        with open('color_data.txt','w') as f:
            f.write(str(s1))
            f.write(str(s2))
        print("s1:",s1)
        print("s2:",s2)
        print("data_1:",data_1)
        print("data_2:",data_2)
        if (hong!=0 and bai!=0 and abs(hong-bai)<5 and data2[2][0] in (s2[0][0],s2[1][0]))or(s1[0][0]=='黑'and s2[0][0]=='黑'and hong>1) or (s2[0][0]=='红') or (bai==0 and hei!=0 and hong!=0):
            print('红','1')
            break
        elif (s1[0][0]=='黑' and s2[0][0]=='黑')or (s1[0][0]=='黑' and s2[1][0]=='黑' and s1[0][1]>4000):
            print('黑','2')
            break
        elif (s2[0][0]=='白'and (data2[1][0] in (s1[0][0],s1[1][0])))or(s1[0][0]=='白'and (data2[1][0] in (s2[0][0],s2[1][0])))or(white2!=0 and (data2[1][0] in (s1[0][0],s1[1][0])) and (float(white1/white)>0.85)) or(data2[1][0] in(s1[0][0],s1[1][0]) and data2[1][0] in (s2[0][0],s2[1][0]) and s2[1][0]=='白'and float(s2[1][1]/s2[0][1])>0.5):
            print('白','3')
            break
#         elif s1[0][1]>5000 and (s1[0][0] in(s2[0][0],s2[1][0])):
#             print(s1[0][0],'3')
#             break
#         elif s2[0][0]=='黑' and s1[0][0]=='黑' and s1[0][1]>1500:
#             print('黑','4')
#             break
        else:
            print(s1[0][0],'5')
            break
        break
print(Y)
# Out:
# (4944, (44, 83, 112), '#2C5370', '蓝')
# (304, (43, 84, 114), '#2B5472', '蓝')
# (186, (43, 84, 112), '#2B5470', '蓝')
# (172, (46, 83, 112), '#2E5370', '蓝')
# (163, (104, 113, 108), '#68716C', '暗淡的灰')
# (160, (102, 113, 109), '#66716D', '暗淡的灰')
# (152, (103, 112, 107), '#67706B', '暗淡的灰')
# (152, (44, 84, 110), '#2C546E', '蓝')
# (149, (104, 115, 111), '#68736F', '暗淡的灰')
# (148, (46, 83, 110), '#2E536E', '蓝')
# (147, (98, 111, 104), '#626F68', '暗淡的灰')
# (144, (104, 113, 110), '#68716E', '暗淡的灰')
# (135, (102, 113, 107), '#66716B', '暗淡的灰')
# (131, (102, 111, 106), '#666F6A', '暗淡的灰')
# (130, (105, 114, 111), '#69726F', '暗淡的灰')
# (129, (102, 114, 110), '#66726E', '暗淡的灰')
# (125, (102, 113, 105), '#667169', '暗淡的灰')
# (124, (95, 102, 94), '#5F665E', '暗淡的灰')
# (122, (102, 115, 108), '#66736C', '暗淡的灰')
# (119, (102, 111, 108), '#666F6C', '暗淡的灰')
# (116, (103, 114, 110), '#67726E', '暗淡的灰')
# (113, (105, 116, 112), '#697470', '白')
# (112, (103, 113, 105), '#677169', '暗淡的灰')
# (112, (53, 54, 58), '#35363A', '灰黑')
# (107, (105, 114, 109), '#69726D', '暗淡的灰')
# (106, (104, 114, 106), '#68726A', '暗淡的灰')
# (103, (102, 112, 104), '#667068', '暗淡的灰')
# (102, (103, 114, 108), '#67726C', '暗淡的灰')
# (101, (98, 110, 106), '#626E6A', '暗淡的灰')
# (101, (43, 45, 40), '#2B2D28', '黑')
# (100, (44, 83, 114), '#2C5372', '蓝')
# (99, (95, 106, 100), '#5F6A64', '暗淡的灰')
# (98, (95, 106, 102), '#5F6A66', '暗淡的灰')
# (98, (52, 53, 57), '#343539', '灰黑')
# (95, (30, 30, 30), '#1E1E1E', '黑')
# (94, (100, 111, 105), '#646F69', '暗淡的灰')
# (92, (101, 114, 107), '#65726B', '暗淡的灰')
# (92, (99, 110, 104), '#636E68', '暗淡的灰')
# (92, (96, 103, 95), '#60675F', '暗淡的灰')
# (91, (100, 109, 106), '#646D6A', '暗淡的灰')
# (90, (94, 101, 94), '#5E655E', '暗淡的灰')
# (88, (101, 112, 106), '#65706A', '暗淡的灰')
# (88, (92, 102, 93), '#5C665D', '暗淡的灰')
# (87, (103, 112, 109), '#67706D', '暗淡的灰')
# (87, (43, 85, 110), '#2B556E', '蓝')
# s1: [('黑', 196), ('白', 113), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# s2: [('黑', 2), ('白', 1), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_1: [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# data_2: [('黑', 0), ('白', 0), ('红', 0), ('蓝', 0), ('灰', 0), ('银', 0)]
# 黑 2
# 0
